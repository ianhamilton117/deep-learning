# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

# t is a hyperparameter that should be tuned
t = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - (t / freqs[word])**0.5 for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size + 1)
    low = idx - R if (idx - R) > 0 else 0
    high = idx + R + 1
    target = set(words[low:idx] + words[idx + 1 : high])
    return list(target)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    with tf.name_scope("inputs"):
        inputs = tf.placeholder(tf.int32, [None], name="inputs")
    with tf.name_scope("labels"):
        labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
from tensorflow.contrib.tensorboard.plugins import projector

n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    with tf.name_scope("embedding"):
        embedding_var = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1), name='word_embedding') # create embedding weight matrix here
        embed = tf.nn.embedding_lookup(embedding_var, inputs) # use tf.nn.embedding_lookup to get the hidden layer output
        tf.summary.histogram("word_embedding", embedding_var)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    with tf.name_scope("softmax"):
        softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
        softmax_b = tf.Variable(tf.zeros((n_vocab))) # create softmax biases here
        tf.summary.histogram("softmax_w", softmax_w)
        tf.summary.histogram("softmax_b", softmax_b)
    
    with tf.name_scope("cost"):
        # Calculate the loss using negative sampling
        loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
        
        cost = tf.reduce_mean(loss)
        tf.summary.scalar("cost", cost)
        
    with tf.name_scope("train"):
        optimizer = tf.train.AdamOptimizer().minimize(cost)
        
    merged = tf.summary.merge_all()

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding_var), 1, keep_dims=True))
    normalized_embedding = embedding_var / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())
    train_writer = tf.summary.FileWriter('./logs/train', sess.graph)
    #test_writer = tf.summary.FileWriter('./logs/test')

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            summary, train_loss, _ = sess.run([merged, cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            train_writer.add_summary(summary, iteration)
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6876 0.8393 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5848 0.8545 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4862 0.8270 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5970 0.8539 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5267 0.8602 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5467 0.8643 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5349 0.8748 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5430 0.8772 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4805 0.8825 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4585 0.9266 sec/batch
# Nearest to see: crimes, attend, fertility, gebhard, ahn, motorcyclist, bibliographer, archaeologists,
# Nearest to d: avro, aikman, audit, renminbi, yugoslavian, ill, drosophila, non,
# Nearest to between: michio, coined, pomp, reflexivity, machaut, marshals, grew, pel,
# Nearest to who: impressed, unions, mentors, montes, mountaineering, clades, whirling, keen,
# Nearest to known: neutrons, scientifically, handful, tatum, annunciation, assigned, dostum, scottish,
# Nearest to no: fcc, transcend, comply, burmese, mits, nite, tyrant, vibe,
# Nearest to also: francium, canonization, transliterations, munch, tikal, nitrite, located, abilities,
# Nearest to th: economists, fremen, rescuing, landmark, molson, matilda, hired, warmest,
# Nearest to road: apek, signatory, kournikova, fireball, nunn, connick, fleurs, pioneer,
# Nearest to pressure: secretive, instant, renunciation, animator, mozambicans, naturalizing, flavian, deportivo,
# Nearest to writers: replenishment, harum, unaware, contribution, talisman, heron, trichomes, boulders,
# Nearest to award: veneziano, lime, rewritable, earthlike, nitz, logrus, teos, cryptozoology,
# Nearest to recorded: expanded, guideline, rallying, aris, wendt, magellan, sunlight, mestres,
# Nearest to something: hillside, aptly, neither, customary, weekend, packer, calc, nephropathy,
# Nearest to additional: authorizes, papas, paraphilia, celsus, shortness, tombstones, carcass, cramps,
# Nearest to report: honour, mercilessly, ottokar, cisternae, rove, metzger, device, recommends,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4746 0.9458 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4000 0.9766 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3434 0.9207 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2455 0.9043 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1937 0.9054 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1951 0.9098 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0874 0.9121 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0540 0.9126 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0209 0.9122 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9948 0.9176 sec/batch
# Nearest to see: attend, crimes, fertility, places, ongoing, heading, gebhard, ahn,
# Nearest to d: avro, non, audit, ill, aikman, concerned, twenty, renminbi,
# Nearest to between: coined, grew, best, reflexivity, pomp, come, marshals, chuck,
# Nearest to who: unions, impressed, especially, perpetuity, whirling, keen, conquests, whole,
# Nearest to known: handful, assigned, scientifically, neutrons, scottish, annunciation, levels, slumber,
# Nearest to no: transcend, comply, a, million, fcc, case, depending, tyrant,
# Nearest to also: francium, located, abilities, transliterations, canonization, well, dispute, appreciating,
# Nearest to th: economists, fremen, landmark, hired, rescuing, obtained, microscopic, scholarship,
# Nearest to road: signatory, apek, connick, nunn, pioneer, fireball, kournikova, africa,
# Nearest to pressure: secretive, instant, modifiers, insides, animator, naturalizing, renunciation, msrp,
# Nearest to writers: unaware, replenishment, contribution, expected, negotiate, all, boilers, harum,
# Nearest to award: veneziano, lime, obstacle, disputes, rico, edition, logrus, nitz,
# Nearest to recorded: expanded, structure, guideline, symptoms, rallying, aris, lives, king,
# Nearest to something: neither, customary, aptly, hillside, folksong, weekend, expensive, continue,
# Nearest to additional: authorizes, celsus, papas, pass, represent, almanac, birkbeck, bin,
# Nearest to report: honour, ottokar, mercilessly, device, dual, assigned, cisternae, recommends,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9408 0.8893 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9248 0.8655 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8712 0.8662 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9004 0.8689 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8247 0.8601 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8094 0.8637 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8004 0.8655 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8125 0.8619 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7906 0.8631 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7811 0.8649 sec/batch
# Nearest to see: attend, crimes, fertility, archaeologists, ongoing, localised, bibliographer, constructs,
# Nearest to d: avro, ill, audit, pedagogues, non, aikman, occurring, renminbi,
# Nearest to between: pomp, coined, reflexivity, schematic, marshals, marx, grew, pel,
# Nearest to who: unions, impressed, keen, perpetuity, conquests, revive, mentors, whirling,
# Nearest to known: handful, scientifically, assigned, neutrons, annunciation, scottish, professions, phil,
# Nearest to no: comply, transcend, burmese, million, fcc, documented, a, elaborate,
# Nearest to also: francium, canonization, abilities, located, munch, appreciating, organic, transliterations,
# Nearest to th: economists, fremen, landmark, rescuing, hired, convergence, matilda, scholarship,
# Nearest to road: signatory, connick, nunn, pioneer, apek, africa, committees, guitar,
# Nearest to pressure: secretive, modifiers, instant, insides, renunciation, animator, pastor, msrp,
# Nearest to writers: unaware, contribution, replenishment, expected, negotiate, reruns, all, doomed,
# Nearest to award: obstacle, rico, lime, veneziano, edition, logrus, zolt, pertinent,
# Nearest to recorded: expanded, guideline, magellan, aris, rallying, poet, sunlight, structure,
# Nearest to something: customary, neither, hillside, aptly, weekend, folksong, downfall, extinctions,
# Nearest to additional: authorizes, celsus, papas, pass, almanac, synoptic, carcass, shortness,
# Nearest to report: honour, mercilessly, dual, ottokar, html, assigned, recommends, device,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7625 0.9053 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7747 0.9780 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7185 0.9539 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7049 0.9502 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7422 0.9434 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6957 0.9383 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6903 0.9339 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7077 0.9322 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6938 0.9395 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6637 0.9455 sec/batch
# Nearest to see: attend, fertility, archaeologists, localised, crimes, aids, idiosyncrasies, bibliographer,
# Nearest to d: avro, ill, audit, pedagogues, publius, television, poet, aikman,
# Nearest to between: schematic, pomp, marshals, marx, reflexivity, coined, pel, michio,
# Nearest to who: keen, impressed, mentors, unions, revive, conquests, whirling, spades,
# Nearest to known: scientifically, handful, neutrons, assigned, annunciation, dostum, tallow, slumber,
# Nearest to no: comply, transcend, alleviate, fcc, burmese, upsurge, a, mits,
# Nearest to also: francium, canonization, tikal, abilities, appreciating, located, crimp, flare,
# Nearest to th: economists, rescuing, landmark, matilda, fremen, abroad, convergence, hired,
# Nearest to road: signatory, apek, connick, pioneer, committees, africa, nunn, complained,
# Nearest to pressure: secretive, modifiers, adp, insides, renunciation, instant, subsistence, msrp,
# Nearest to writers: unaware, replenishment, contribution, reruns, harum, expected, talisman, heron,
# Nearest to award: rico, obstacle, logrus, zolt, greig, edition, rewritable, nitz,
# Nearest to recorded: expanded, guideline, aris, magellan, compositional, beltway, rallying, poet,
# Nearest to something: neither, hillside, customary, aptly, extinctions, weekend, wallets, forbade,
# Nearest to additional: authorizes, celsus, papas, pass, birkbeck, shortness, almanac, synoptic,
# Nearest to report: honour, mercilessly, ottokar, della, ladino, dual, html, metzger,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6554 0.9019 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6722 0.8790 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6083 0.8834 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6055 0.8851 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6087 0.8773 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6176 0.8809 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5904 0.6639 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5422 0.8777 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4997 0.8770 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5127 0.8778 sec/batch
# Nearest to see: localised, archaeologists, fertility, attend, constructs, idiosyncrasies, motorcyclist, function,
# Nearest to d: poet, avro, b, laureate, steve, eight, ill, recipient,
# Nearest to between: schematic, marx, specifics, pomp, reflexivity, marshals, michio, pel,
# Nearest to who: impressed, keen, mentors, zog, unions, conquests, mgh, spades,
# Nearest to known: neutrons, scientifically, handful, annunciation, assigned, dostum, dunfermline, tallow,
# Nearest to no: comply, transcend, burmese, fcc, a, alleviate, earthlink, depending,
# Nearest to also: francium, delphi, canonization, attersee, abilities, crimp, appreciating, adapa,
# Nearest to th: economists, rescuing, landmark, matilda, abroad, scholarship, convergence, fremen,
# Nearest to road: apek, signatory, committees, kournikova, connick, nunn, fireball, pioneer,
# Nearest to pressure: secretive, detonator, modifiers, msrp, narrowing, insides, subsistence, adp,
# Nearest to writers: unaware, contribution, replenishment, reruns, talisman, harum, fiction, literature,
# Nearest to award: zolt, logrus, rico, edition, teos, greig, rewritable, hacked,
# Nearest to recorded: aris, guideline, flashes, compositional, expanded, archaeologists, wendt, nasty,
# Nearest to something: neither, hillside, aptly, customary, extinctions, wallets, said, forbade,
# Nearest to additional: authorizes, celsus, pass, papas, shortness, represent, birkbeck, synoptic,
# Nearest to report: honour, mercilessly, ottokar, metzger, ladino, rockingham, della, html,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4935 0.9554 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5005 0.9350 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4471 0.9399 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5311 0.9455 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4882 0.9311 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4791 0.9395 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4759 0.9424 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4059 0.9330 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4335 0.9344 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4104 0.9364 sec/batch
# Nearest to see: localised, idiosyncrasies, archaeologists, fertility, motorcyclist, samba, bibliographer, constructs,
# Nearest to d: avro, owen, publius, pedagogues, ill, steve, aleksandr, aikman,
# Nearest to between: schematic, marx, specifics, grids, pomp, reflexivity, inaccurate, pel,
# Nearest to who: keen, impressed, mentors, unions, zog, mgh, zeus, conquests,
# Nearest to known: scientifically, neutrons, handful, dunfermline, annunciation, assigned, dostum, scottish,
# Nearest to no: comply, transcend, burmese, mits, earthlink, a, depending, erythromycin,
# Nearest to also: francium, delphi, attersee, appreciating, flare, crimp, abilities, adapa,
# Nearest to th: economists, landmark, congo, matilda, holy, rescuing, abroad, anaphylaxis,
# Nearest to road: apek, kournikova, signatory, committees, wooden, nunn, africa, connick,
# Nearest to pressure: secretive, msrp, detonator, modifiers, narrowing, subsistence, reactions, adp,
# Nearest to writers: unaware, harum, contribution, literature, replenishment, reruns, fiction, lad,
# Nearest to award: zolt, edition, rico, logrus, rewritable, teos, veneziano, greig,
# Nearest to recorded: aris, wendt, flashes, expanded, archaeologists, enquiry, compositional, nasty,
# Nearest to something: neither, hillside, extinctions, aptly, said, customary, wallets, cmf,
# Nearest to additional: authorizes, celsus, pass, shortness, represent, papas, header, associative,
# Nearest to report: honour, ottokar, metzger, mercilessly, ladino, della, html, unmistakable,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4457 0.9261 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4100 0.8854 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4170 0.8834 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3846 0.8814 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4226 0.8758 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4390 0.8849 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3666 0.8865 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3766 0.8761 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4296 0.8829 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3593 0.8966 sec/batch
# Nearest to see: localised, motorcyclist, idiosyncrasies, bibliographer, samba, archaeologists, sunnm, ongoing,
# Nearest to d: avro, owen, critic, publius, pedagogues, b, toonopedia, alphonse,
# Nearest to between: schematic, grids, marx, pel, inaccurate, pomp, specifics, uzbekistan,
# Nearest to who: keen, impressed, mentors, zeus, wither, revive, mgh, ssn,
# Nearest to known: scientifically, dunfermline, neutrons, handful, scottish, mitten, annunciation, dostum,
# Nearest to no: burmese, transcend, aeaea, mits, comply, a, erythromycin, depending,
# Nearest to also: francium, attersee, delphi, crimp, appreciating, adapa, polygyny, abilities,
# Nearest to th: economists, landmark, rescuing, anaphylaxis, matilda, shepherds, congo, official,
# Nearest to road: apek, kournikova, wooden, committees, signatory, connick, xml, nunn,
# Nearest to pressure: secretive, msrp, detonator, narrowing, reactions, instant, modifiers, adp,
# Nearest to writers: fiction, contribution, harum, unaware, literature, reruns, lad, talisman,
# Nearest to award: zolt, rewritable, edition, logrus, rico, teos, greig, veneziano,
# Nearest to recorded: wendt, aris, compositional, invective, nasty, flashes, expanded, tbs,
# Nearest to something: neither, customary, said, aptly, wallets, hillside, extinctions, cmf,
# Nearest to additional: pass, authorizes, celsus, megabytes, header, shortness, represent, papas,
# Nearest to report: honour, ottokar, metzger, mercilessly, della, unmistakable, nda, rockingham,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3904 0.9879 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3759 0.9382 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3366 0.9413 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3744 0.9375 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4022 0.9424 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3496 0.9421 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3698 0.9340 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3927 0.9429 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3350 0.9399 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3258 0.9093 sec/batch
# Nearest to see: localised, sunnm, bibliographer, motorcyclist, idiosyncrasies, programming, ultraman, samba,
# Nearest to d: avro, owen, toonopedia, pedagogues, aikman, critic, publius, aleksandr,
# Nearest to between: schematic, marx, inaccurate, grids, specifics, profited, penises, pel,
# Nearest to who: keen, impressed, mentors, wither, zeus, spades, mgh, revive,
# Nearest to known: scottish, dunfermline, neutrons, scientifically, annunciation, handful, dostum, ablaut,
# Nearest to no: aeaea, transcend, mits, burmese, earthlink, comply, sifre, vicu,
# Nearest to also: attersee, francium, crimp, polygyny, delphi, organic, adapa, appreciating,
# Nearest to th: economists, anaphylaxis, shepherds, landmark, molson, rescuing, decline, holy,
# Nearest to road: apek, wooden, kournikova, xml, committees, connick, signatory, pioneer,
# Nearest to pressure: secretive, msrp, detonator, adp, reactions, narrowing, instant, subsistence,
# Nearest to writers: fiction, contribution, harum, unaware, literature, lad, reruns, talisman,
# Nearest to award: zolt, rewritable, logrus, edition, greig, rohan, teos, keweenaw,
# Nearest to recorded: wendt, aris, flashes, tbs, compositional, nasty, channelled, enquiry,
# Nearest to something: neither, said, aptly, customary, wallets, hillside, cmf, packer,
# Nearest to additional: celsus, authorizes, pass, represent, header, megabytes, birkbeck, shortness,
# Nearest to report: honour, ottokar, metzger, mercilessly, unmistakable, rockingham, nda, ladino,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3218 0.9038 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2672 0.8868 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3794 0.8743 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3596 0.8736 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3883 0.8736 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2789 0.8755 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3051 0.8999 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3040 0.9602 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1948 0.9821 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2933 0.9800 sec/batch
# Nearest to see: localised, bibliographer, motorcyclist, sunnm, links, programming, idiosyncrasies, history,
# Nearest to d: b, avro, critic, aleksandr, laureate, recipient, alphonse, poet,
# Nearest to between: schematic, marx, grids, inaccurate, profited, kinship, pel, uzbekistan,
# Nearest to who: keen, impressed, mentors, wither, ssn, whirling, zog, mgh,
# Nearest to known: scottish, dunfermline, annunciation, scientifically, neutrons, mitten, shapiro, newall,
# Nearest to no: mits, burmese, transcend, aeaea, earthlink, sifre, comply, erythromycin,
# Nearest to also: attersee, crimp, polygyny, francium, hamiltonians, organic, hwa, delphi,
# Nearest to th: anaphylaxis, landmark, economists, shepherds, leap, molson, rescuing, congo,
# Nearest to road: apek, kournikova, wooden, committees, xml, connick, hyderabad, fireball,
# Nearest to pressure: secretive, detonator, msrp, adp, subsistence, narrowing, reversibility, instant,
# Nearest to writers: fiction, literature, contribution, harum, unaware, talisman, lad, reruns,
# Nearest to award: rewritable, zolt, rohan, stan, keweenaw, logrus, veneziano, demoralized,
# Nearest to recorded: wendt, tbs, compositional, recording, flashes, nasty, channelled, rhythm,
# Nearest to something: neither, said, aptly, wallets, customary, profess, cmf, nephropathy,
# Nearest to additional: pass, celsus, authorizes, represent, birkbeck, header, insufflated, megabytes,
# Nearest to report: honour, ottokar, metzger, mercilessly, nda, oppositions, breatharianism, html,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2819 1.0421 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2870 1.0146 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3577 0.4886 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2417 0.9684 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2274 0.9715 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2031 0.9990 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2284 0.9785 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2238 0.9736 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2252 0.9818 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1876 1.0506 sec/batch
# Nearest to see: sunnm, history, motorcyclist, links, bibliographer, samba, localised, idiosyncrasies,
# Nearest to d: avro, b, aleksandr, alphonse, pedagogues, critic, recipient, owen,
# Nearest to between: schematic, grids, uzbekistan, inaccurate, than, marx, pel, machaut,
# Nearest to who: keen, impressed, ssn, mentors, wither, trifling, perpetuity, zeus,
# Nearest to known: dunfermline, scottish, annunciation, neutrons, scientifically, architect, mitten, ablaut,
# Nearest to no: mits, burmese, transcend, aeaea, father, earthlink, sifre, erythromycin,
# Nearest to also: attersee, crimp, hwa, organic, francium, polygyny, appreciating, hamiltonians,
# Nearest to th: leap, anaphylaxis, economists, landmark, shepherds, molson, holy, arrondissement,
# Nearest to road: apek, kournikova, wooden, xml, committees, hyderabad, fireball, maradns,
# Nearest to pressure: secretive, detonator, msrp, adp, narrowing, instant, reversibility, subsistence,
# Nearest to writers: fiction, literature, harum, talisman, lad, contribution, biography, unaware,
# Nearest to award: zolt, rewritable, stan, keweenaw, medal, veneziano, greig, logrus,
# Nearest to recorded: wendt, recording, peotone, rhythm, flashes, channelled, nasty, compositional,
# Nearest to something: neither, aptly, said, wallets, cmf, folksong, profess, customary,
# Nearest to additional: pass, authorizes, celsus, birkbeck, header, insufflated, megabytes, represent,
# Nearest to report: honour, ottokar, nda, metzger, html, oppositions, breatharianism, mercilessly,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2419 0.9829 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2067 0.9648 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2216 0.9611 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1038 0.9682 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1633 0.9665 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1678 0.9615 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1534 0.9634 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2085 0.9601 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1838 0.9730 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1824 0.9774 sec/batch
# Nearest to see: sunnm, ongoing, localised, history, samba, motorcyclist, links, idiosyncrasies,
# Nearest to d: avro, aikman, b, pedagogues, friedlander, aleksandr, toonopedia, owen,
# Nearest to between: schematic, grids, inaccurate, uzbekistan, marx, than, kinship, habitability,
# Nearest to who: keen, impressed, ssn, mentors, importantly, trifling, perpetuity, wither,
# Nearest to known: scottish, mitten, neutrons, annunciation, dunfermline, saturated, scientifically, ablaut,
# Nearest to no: mits, transcend, burmese, earthlink, depending, comply, aeaea, father,
# Nearest to also: organic, attersee, crimp, polygyny, francium, appreciating, hwa, hamiltonians,
# Nearest to th: anaphylaxis, leap, shepherds, landmark, molson, century, arrondissement, economists,
# Nearest to road: apek, kournikova, wooden, connick, xml, fireball, maradns, hyderabad,
# Nearest to pressure: secretive, msrp, detonator, narrowing, instant, adp, reversibility, modifiers,
# Nearest to writers: fiction, literature, harum, contribution, talisman, lad, bergerac, births,
# Nearest to award: rewritable, zolt, elway, keweenaw, chung, medal, opener, veneziano,
# Nearest to recorded: wendt, peotone, tbs, recording, rhythm, nasty, cabrera, compositional,
# Nearest to something: neither, aptly, wallets, said, folksong, cmf, profess, packer,
# Nearest to additional: pass, authorizes, celsus, insufflated, megabytes, birkbeck, header, mingw,
# Nearest to report: honour, ottokar, nda, metzger, html, oppositions, breatharianism, announced,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1577 0.9831 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2474 0.9156 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1717 0.8796 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1449 0.8830 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2018 0.8761 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1611 0.8777 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2038 0.8789 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1650 0.8779 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1462 0.9161 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1878 0.8778 sec/batch
# Nearest to see: sunnm, ongoing, idiosyncrasies, samba, history, links, motorcyclist, localised,
# Nearest to d: avro, b, aikman, aleksandr, pedagogues, friedlander, toonopedia, owen,
# Nearest to between: schematic, inaccurate, grids, than, marx, pel, kinship, uzbekistan,
# Nearest to who: keen, impressed, ssn, mentors, importantly, perpetuity, revive, trifling,
# Nearest to known: scottish, ablaut, neutrons, annunciation, scientifically, adopt, mitten, newall,
# Nearest to no: mits, transcend, father, aeaea, micah, burmese, earthlink, transhumanist,
# Nearest to also: organic, crimp, polygyny, attersee, hwa, adapa, hamiltonians, francium,
# Nearest to th: anaphylaxis, leap, landmark, molson, convergence, arrondissement, century, shepherds,
# Nearest to road: kournikova, wooden, apek, xml, maradns, fireball, hyderabad, connick,
# Nearest to pressure: secretive, msrp, detonator, instant, reversibility, adp, narrowing, insides,
# Nearest to writers: fiction, harum, literature, talisman, contribution, lad, unaware, bergerac,
# Nearest to award: rewritable, zolt, elway, veneziano, medal, greig, keweenaw, opener,
# Nearest to recorded: wendt, recording, tbs, nasty, peotone, rhythm, expanded, cabrera,
# Nearest to something: neither, folksong, aptly, said, wallets, cmf, nephropathy, karaite,
# Nearest to additional: pass, celsus, authorizes, insufflated, block, birkbeck, mingw, header,
# Nearest to report: honour, ottokar, nda, breatharianism, metzger, html, announced, oppositions,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2191 0.8879 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1523 0.9099 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2051 0.9588 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2004 0.9436 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1449 0.9501 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1508 0.9502 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1648 0.9538 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1166 0.9516 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2199 0.9653 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1841 0.9434 sec/batch
# Nearest to see: history, links, ongoing, motorcyclist, sunnm, bibliographer, idiosyncrasies, com,
# Nearest to d: b, avro, aleksandr, recipient, aikman, conductor, critic, alphonse,
# Nearest to between: schematic, uzbekistan, inaccurate, pel, marx, grids, kinship, than,
# Nearest to who: keen, impressed, ssn, perpetuity, importantly, whirling, mentors, wither,
# Nearest to known: scottish, annunciation, ablaut, newall, adopt, neutrons, dunfermline, arcy,
# Nearest to no: mits, transcend, father, micah, burmese, aeaea, comply, earthlink,
# Nearest to also: organic, hwa, adapa, hamiltonians, polygyny, attersee, crimp, porpoises,
# Nearest to th: leap, anaphylaxis, century, landmark, arrondissement, rescuing, molson, decline,
# Nearest to road: kournikova, apek, wooden, xml, connick, maradns, hyderabad, fireball,
# Nearest to pressure: secretive, msrp, detonator, reversibility, instant, adp, narrowing, renunciation,
# Nearest to writers: fiction, harum, literature, illustrators, births, bergerac, talisman, contribution,
# Nearest to award: rewritable, medal, zolt, elway, veneziano, keweenaw, greig, folsom,
# Nearest to recorded: wendt, recording, rhythm, nasty, tbs, peotone, cabrera, compositional,
# Nearest to something: neither, folksong, said, aptly, wallets, profess, nephropathy, cmf,
# Nearest to additional: authorizes, pass, celsus, insufflated, block, header, mingw, birkbeck,
# Nearest to report: honour, announced, breatharianism, april, ottokar, html, nda, metzger,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2238 0.9565 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1235 0.9398 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1338 0.9204 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1201 0.8765 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0358 0.8813 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1765 0.8788 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1409 0.8789 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1417 0.8773 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1888 0.2211 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1098 0.8771 sec/batch
# Nearest to see: history, samba, links, sunnm, jp, ongoing, disambiguation, com,
# Nearest to d: b, avro, aikman, conductor, aleksandr, philologist, pedagogues, recipient,
# Nearest to between: schematic, uzbekistan, grids, inaccurate, pel, marx, kinship, habitability,
# Nearest to who: keen, impressed, ssn, importantly, wither, waive, somebody, perpetuity,
# Nearest to known: scottish, ablaut, annunciation, adopt, neutrons, scientifically, newall, arcy,
# Nearest to no: mits, transcend, burmese, micah, father, earthlink, aeaea, transhumanist,
# Nearest to also: hwa, organic, the, crimp, attersee, polygyny, adapa, francium,
# Nearest to th: century, landmark, anaphylaxis, leap, molson, shepherds, arrondissement, decline,
# Nearest to road: kournikova, apek, wooden, xml, maradns, hyderabad, connick, connect,
# Nearest to pressure: detonator, secretive, msrp, reversibility, instant, adp, narrowing, insides,
# Nearest to writers: fiction, literature, harum, talisman, illustrators, births, bergerac, lad,
# Nearest to award: rewritable, medal, academy, elway, zolt, veneziano, greig, keweenaw,
# Nearest to recorded: wendt, recording, nasty, rhythm, peotone, cabrera, compositional, enquiry,
# Nearest to something: neither, aptly, folksong, profess, wallets, said, couldn, nephropathy,
# Nearest to additional: pass, block, header, authorizes, insufflated, mingw, megabytes, celsus,
# Nearest to report: honour, announced, oppositions, april, breatharianism, arrested, ottokar, html,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0532 0.8820 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0814 0.8775 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1057 0.8988 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0625 0.9366 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0971 0.9340 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0281 0.9401 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0854 0.9414 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0984 0.9209 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1337 0.9589 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0283 0.9364 sec/batch
# Nearest to see: history, samba, links, sunnm, ongoing, com, disambiguation, jp,
# Nearest to d: avro, aikman, pedagogues, b, gairy, engraver, conductor, toonopedia,
# Nearest to between: schematic, uzbekistan, pel, grids, kinship, inaccurate, newt, habitability,
# Nearest to who: keen, impressed, ssn, importantly, forged, boxes, waive, perpetuity,
# Nearest to known: scottish, ablaut, adopt, annunciation, scientifically, neutrons, most, shapiro,
# Nearest to no: mits, transcend, burmese, father, residing, micah, earthlink, grudging,
# Nearest to also: organic, hwa, the, crimp, hamiltonians, uachtar, skins, attersee,
# Nearest to th: century, leap, landmark, anaphylaxis, decline, molson, arrondissement, shepherds,
# Nearest to road: kournikova, apek, wooden, xml, maradns, connect, brick, nunn,
# Nearest to pressure: detonator, secretive, msrp, reversibility, instant, narrowing, adp, activates,
# Nearest to writers: fiction, literature, harum, illustrators, births, contribution, talisman, bergerac,
# Nearest to award: rewritable, zolt, medal, veneziano, elway, academy, keweenaw, awarded,
# Nearest to recorded: recording, wendt, nasty, rhythm, peotone, enquiry, cabrera, compositional,
# Nearest to something: neither, folksong, profess, aptly, wallets, nephropathy, couldn, said,
# Nearest to additional: block, header, pass, mingw, authorizes, insufflated, megabytes, represent,
# Nearest to report: april, html, announced, honour, oppositions, arrested, ottokar, breatharianism,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0221 0.9423 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0474 0.9360 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0317 0.9073 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0669 0.8737 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0698 0.8778 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0414 0.8806 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0783 0.8731 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1296 0.8854 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0516 0.8822 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0495 0.8809 sec/batch
# Nearest to see: ongoing, sunnm, samba, history, links, jp, disambiguation, bibliographer,
# Nearest to d: avro, aikman, b, pianists, gairy, croce, pedagogues, toonopedia,
# Nearest to between: schematic, inaccurate, grids, marx, than, uzbekistan, kinship, electroplating,
# Nearest to who: keen, impressed, importantly, ssn, trifling, addressee, waive, somebody,
# Nearest to known: scottish, ablaut, adopt, most, neutrons, annunciation, scientifically, phil,
# Nearest to no: mits, transcend, micah, earthlink, father, residing, burmese, transhumanist,
# Nearest to also: organic, the, hwa, polygyny, in, hamiltonians, skins, appreciating,
# Nearest to th: century, anaphylaxis, landmark, molson, leap, arrondissement, decline, albemarle,
# Nearest to road: kournikova, apek, wooden, xml, maradns, connick, nunn, brick,
# Nearest to pressure: msrp, reversibility, detonator, secretive, instant, narrowing, adp, exerts,
# Nearest to writers: fiction, harum, literature, births, illustrators, poets, contribution, talisman,
# Nearest to award: rewritable, medal, zolt, preclear, academy, awarded, veneziano, elway,
# Nearest to recorded: recording, wendt, nasty, peotone, cabrera, rhythm, tbs, archaeologists,
# Nearest to something: neither, folksong, wallets, profess, aptly, nephropathy, incorruptible, said,
# Nearest to additional: block, insufflated, header, pass, mingw, authorizes, megabytes, represent,
# Nearest to report: announced, breatharianism, oppositions, april, arrested, recommends, honour, kouchner,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0702 0.8761 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0595 0.8763 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0934 0.8930 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0437 0.9338 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0633 0.9345 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0516 0.9281 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0603 0.9357 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0642 0.9539 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0771 0.9322 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0780 0.9337 sec/batch
# Nearest to see: links, ongoing, history, bibliographer, sunnm, disambiguation, samba, idiosyncrasies,
# Nearest to d: avro, aikman, gairy, credible, pianists, toonopedia, croce, b,
# Nearest to between: schematic, newt, inaccurate, uzbekistan, pel, jinnah, marx, grids,
# Nearest to who: keen, impressed, importantly, trifling, ssn, addressee, perpetuity, waive,
# Nearest to known: scottish, ablaut, adopt, most, annunciation, neutrons, as, dunfermline,
# Nearest to no: mits, transcend, earthlink, micah, father, aeaea, burmese, residing,
# Nearest to also: hwa, organic, the, polygyny, in, role, attersee, well,
# Nearest to th: century, anaphylaxis, albemarle, molson, landmark, decline, arrondissement, leap,
# Nearest to road: kournikova, apek, brick, xml, maradns, wooden, connect, hyderabad,
# Nearest to pressure: msrp, reversibility, detonator, instant, secretive, adp, narrowing, exerts,
# Nearest to writers: fiction, births, illustrators, harum, literature, poets, contribution, novelists,
# Nearest to award: medal, rewritable, awarded, zolt, academy, preclear, veneziano, greig,
# Nearest to recorded: recording, wendt, cabrera, nasty, rhythm, peotone, monticello, enquiry,
# Nearest to something: neither, folksong, wallets, aptly, incorruptible, profess, nephropathy, couldn,
# Nearest to additional: insufflated, block, authorizes, pass, header, almanac, celsus, mingw,
# Nearest to report: arrested, announced, april, ottokar, breatharianism, oppositions, kouchner, headline,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0687 0.9430 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0189 0.9310 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0575 0.9157 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0600 0.8826 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0717 0.8757 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1215 0.8714 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1237 0.8745 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0593 0.8732 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0019 0.8932 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0616 0.8736 sec/batch
# Nearest to see: links, bibliographer, history, samba, disambiguation, ongoing, ultraman, sunnm,
# Nearest to d: avro, aikman, gairy, b, critic, pianists, croce, engraver,
# Nearest to between: schematic, newt, inaccurate, pel, uzbekistan, grids, marx, multipole,
# Nearest to who: keen, impressed, importantly, trifling, ssn, addressee, perpetuity, lifestyle,
# Nearest to known: scottish, ablaut, most, annunciation, phil, adopt, neutrons, arcy,
# Nearest to no: mits, transcend, micah, earthlink, father, burmese, ase, residing,
# Nearest to also: organic, the, hwa, polygyny, a, attersee, appreciating, in,
# Nearest to th: century, landmark, anaphylaxis, albemarle, molson, leap, arrondissement, decline,
# Nearest to road: kournikova, apek, maradns, xml, brick, connick, challenging, wooden,
# Nearest to pressure: msrp, detonator, reversibility, secretive, instant, narrowing, exerts, adp,
# Nearest to writers: fiction, births, illustrators, novelists, literature, poets, harum, bergerac,
# Nearest to award: medal, awarded, rewritable, zolt, academy, preclear, intervarsity, emmy,
# Nearest to recorded: recording, wendt, cabrera, nirvana, nasty, peotone, rhythm, live,
# Nearest to something: neither, profess, wallets, aptly, incorruptible, folksong, nephropathy, couldn,
# Nearest to additional: block, authorizes, insufflated, header, pass, mingw, represent, almanac,
# Nearest to report: arrested, announced, headline, april, ottokar, oppositions, scientifique, detained,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9618 0.8824 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0163 0.8803 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0184 0.8907 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0410 0.9457 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0706 0.9359 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0196 0.9401 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9891 0.9372 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9662 0.9404 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0230 0.9509 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9954 0.9334 sec/batch
# Nearest to see: links, samba, disambiguation, history, bibliographer, ongoing, ultraman, updated,
# Nearest to d: aikman, avro, gairy, critic, phine, croce, b, conductor,
# Nearest to between: schematic, newt, uzbekistan, grids, jinnah, pel, iasi, electroplating,
# Nearest to who: keen, importantly, trifling, impressed, ssn, addressee, forged, lifestyle,
# Nearest to known: scottish, most, ablaut, as, adopt, annunciation, recruited, neutrons,
# Nearest to no: micah, mits, transcend, father, burmese, earthlink, ase, aeaea,
# Nearest to also: the, organic, hwa, a, in, well, appreciating, transition,
# Nearest to th: century, albemarle, molson, leap, landmark, anaphylaxis, arrondissement, shepherds,
# Nearest to road: apek, kournikova, maradns, xml, brick, hyderabad, challenging, connect,
# Nearest to pressure: msrp, detonator, reversibility, instant, secretive, narrowing, exerts, adp,
# Nearest to writers: fiction, births, illustrators, novelists, literature, poets, harum, bergerac,
# Nearest to award: medal, awarded, academy, rewritable, zolt, preclear, emmy, intervarsity,
# Nearest to recorded: recording, wendt, nasty, peotone, cabrera, nirvana, live, monticello,
# Nearest to something: neither, incorruptible, wallets, aptly, folksong, profess, couldn, nephropathy,
# Nearest to additional: block, authorizes, header, mingw, insufflated, pass, bains, bud,
# Nearest to report: announced, arrested, headline, recommends, oppositions, detained, april, scientifique,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9821 0.9438 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9514 0.9350 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0210 0.9121 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0085 0.8756 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0305 0.8720 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9790 0.8791 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9513 0.8721 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9995 0.8790 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9219 0.9198 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9747 0.8829 sec/batch
# Nearest to see: links, samba, history, disambiguation, ongoing, bibliographer, figured, shorten,
# Nearest to d: avro, aikman, gairy, croce, yugoslavian, toonopedia, credible, pianists,
# Nearest to between: schematic, newt, jinnah, than, uzbekistan, iasi, inaccurate, habitability,
# Nearest to who: keen, importantly, trifling, ssn, impressed, addressee, forged, boxes,
# Nearest to known: most, as, ablaut, scottish, adopt, saturated, phil, micrometers,
# Nearest to no: mits, micah, residing, transcend, father, ase, calendrical, earthlink,
# Nearest to also: the, organic, in, a, appreciating, hwa, polygyny, skins,
# Nearest to th: century, molson, landmark, albemarle, arrondissement, leap, decline, anaphylaxis,
# Nearest to road: apek, kournikova, maradns, xml, brick, challenging, wooden, connect,
# Nearest to pressure: reversibility, msrp, detonator, instant, secretive, narrowing, adp, exerts,
# Nearest to writers: fiction, births, illustrators, novelists, poets, literature, harum, bergerac,
# Nearest to award: medal, awarded, academy, rewritable, preclear, zolt, emmy, intervarsity,
# Nearest to recorded: recording, wendt, nasty, peotone, cabrera, live, rhythm, nirvana,
# Nearest to something: neither, wallets, folksong, incorruptible, aptly, nephropathy, packer, profess,
# Nearest to additional: block, header, authorizes, mingw, pass, insufflated, almanac, bud,
# Nearest to report: headline, arrested, recommends, detained, oppositions, html, april, announced,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9929 0.8812 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9907 0.8753 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9697 0.9040 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0397 0.9364 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0475 0.9340 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9572 0.9370 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0129 0.9350 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9986 0.9355 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0340 0.9574 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9987 0.9396 sec/batch
# Nearest to see: links, samba, disambiguation, history, figured, ongoing, redrawn, bibliographer,
# Nearest to d: avro, gairy, b, aikman, croce, critic, harold, gli,
# Nearest to between: schematic, newt, pel, bert, multipole, machaut, jinnah, longstanding,
# Nearest to who: importantly, keen, trifling, impressed, ssn, addressee, lifestyle, polly,
# Nearest to known: ablaut, most, as, scottish, adopt, phil, recruited, arcy,
# Nearest to no: mits, micah, earthlink, transcend, father, calendrical, copyrighted, transhumanist,
# Nearest to also: the, organic, a, appreciating, in, hwa, hornsby, with,
# Nearest to th: century, albemarle, molson, leap, landmark, decline, anaphylaxis, arrondissement,
# Nearest to road: kournikova, apek, maradns, brick, connect, traveling, ballad, xml,
# Nearest to pressure: reversibility, msrp, detonator, secretive, instant, narrowing, exerts, adp,
# Nearest to writers: fiction, births, illustrators, novelists, poets, harum, screenwriters, literature,
# Nearest to award: awarded, medal, academy, emmy, preclear, zolt, rewritable, chapin,
# Nearest to recorded: recording, wendt, nasty, cabrera, peotone, rhythm, monticello, nirvana,
# Nearest to something: neither, folksong, wallets, incorruptible, aptly, typology, nephropathy, karaite,
# Nearest to additional: block, pass, authorizes, insufflated, header, mingw, almanac, bud,
# Nearest to report: recommends, headline, arrested, detained, diagnostic, april, oppositions, scientifique,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9947 0.9482 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9594 0.9844 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9844 1.0045 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0184 0.8744 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0238 0.8802 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9904 0.8764 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9756 0.8753 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9733 0.8805 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9718 0.8964 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0126 0.8871 sec/batch
# Nearest to see: links, samba, history, updated, disambiguation, com, ongoing, figured,
# Nearest to d: avro, gairy, aikman, b, croce, critic, yugoslavian, gli,
# Nearest to between: schematic, newt, than, jinnah, multipole, cube, pel, longstanding,
# Nearest to who: trifling, importantly, keen, addressee, ssn, impressed, lifestyle, hisham,
# Nearest to known: most, scottish, as, ablaut, recruited, adopt, phil, arcy,
# Nearest to no: mits, micah, transcend, father, earthlink, copyrighted, calendrical, residing,
# Nearest to also: the, a, in, organic, hwa, with, of, appreciating,
# Nearest to th: century, decline, albemarle, molson, landmark, choirs, leap, anaphylaxis,
# Nearest to road: kournikova, apek, maradns, brick, connect, xml, traveling, hyderabad,
# Nearest to pressure: reversibility, msrp, detonator, secretive, narrowing, instant, exerts, deportivo,
# Nearest to writers: fiction, births, illustrators, novelists, poets, literature, screenwriters, bergerac,
# Nearest to award: awarded, medal, academy, emmy, preclear, intervarsity, chapin, rewritable,
# Nearest to recorded: recording, wendt, nasty, cabrera, enquiry, monticello, nirvana, rhythm,
# ...
# Nearest to see: links, of, also, disambiguation, article, on, in, updated,
# Nearest to d: gairy, tta, avro, harold, teton, audit, boole, b,
# Nearest to between: distinction, other, schematic, of, newt, than, finally, confuse,
# Nearest to who: trifling, polly, upu, jesse, troop, balkline, addressee, forged,
# Nearest to known: as, that, most, with, many, recruited, by, in,
# Nearest to no: import, calendrical, anthropologist, simms, micah, yes, earthlink, eight,
# Nearest to also: a, of, the, in, is, see, with, has,
# Nearest to th: century, leap, molson, albemarle, on, mid, remainder, decline,
# Nearest to road: roads, highways, ballad, brick, ride, zakim, retaking, maradns,
# Nearest to pressure: reversibility, msrp, narrowing, vorticity, secretive, detonator, joule, exerts,
# Nearest to writers: fiction, novelists, illustrators, poets, births, essayists, screenwriters, autodidacts,
# Nearest to award: awarded, awards, best, medal, academy, emmy, outstanding, preclear,
# Nearest to recorded: recording, lp, live, recreate, subsp, cabrera, record, peotone,
# Nearest to something: conant, aptly, say, arrive, couldn, neither, hypnotist, charger,
# Nearest to additional: block, synoptic, header, mingw, separately, pass, vires, insufflated,
# Nearest to report: recommends, conclusions, headline, della, diagnostic, reviewed, wikimedia, exasperated,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8234 0.9302 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8389 0.9211 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8453 0.9168 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8841 0.9150 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8430 0.9298 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8947 0.9017 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8572 0.8728 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8412 0.8721 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8678 0.8635 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8837 0.8890 sec/batch
# Nearest to see: links, of, also, article, disambiguation, on, updated, history,
# Nearest to d: tta, gairy, teton, harold, audit, avro, boole, overthrown,
# Nearest to between: distinction, of, other, schematic, finally, newt, four, urbanised,
# Nearest to who: upu, hisham, trifling, polly, amicable, name, eponym, somebody,
# Nearest to known: as, most, that, with, many, recruited, by, in,
# Nearest to no: import, simms, calendrical, anthropologist, eight, yes, micah, earthlink,
# Nearest to also: a, of, is, the, in, see, with, for,
# Nearest to th: century, leap, molson, albemarle, on, late, anaphylaxis, decline,
# Nearest to road: roads, highways, ballad, ride, brick, maradns, retaking, motorway,
# Nearest to pressure: narrowing, msrp, reversibility, joule, vorticity, secretive, exerts, detonator,
# Nearest to writers: fiction, novelists, illustrators, poets, births, autodidacts, screenwriters, essayists,
# Nearest to award: awarded, best, awards, medal, outstanding, emmy, academy, preclear,
# Nearest to recorded: recording, lp, cabrera, live, record, subsp, wendt, period,
# Nearest to something: conant, aptly, couldn, nonconfirmative, charger, say, karaite, neither,
# Nearest to additional: block, synoptic, separately, header, mingw, vires, insufflated, pass,
# Nearest to report: recommends, conclusions, della, headline, reviewed, diagnostic, arrested, wikimedia,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8612 0.8709 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8473 0.8696 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8361 0.8704 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8520 0.8734 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8986 0.8760 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8259 0.8694 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9715 0.9372 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9113 0.9128 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8795 0.9169 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8327 0.9301 sec/batch
# Nearest to see: links, also, of, disambiguation, article, updated, on, a,
# Nearest to d: gairy, teton, boole, tta, b, avro, harold, audit,
# Nearest to between: four, schematic, other, distinction, newt, of, gillette, finally,
# Nearest to who: upu, troop, hisham, trifling, to, lifestyle, amicable, have,
# Nearest to known: as, most, that, with, by, many, the, photonics,
# Nearest to no: import, simms, anthropologist, calendrical, micah, yes, uncooked, eight,
# Nearest to also: a, the, of, is, see, in, has, with,
# Nearest to th: century, leap, albemarle, remainder, molson, anaphylaxis, late, mid,
# Nearest to road: ballad, highways, roads, brick, ride, retaking, unpaved, maradns,
# Nearest to pressure: narrowing, msrp, reversibility, secretive, vorticity, joule, deportivo, exerts,
# Nearest to writers: fiction, novelists, illustrators, poets, births, autodidacts, alumni, essayists,
# Nearest to award: awarded, best, awards, medal, academy, emmy, outstanding, critically,
# Nearest to recorded: recording, lp, live, cabrera, record, monticello, flightless, lauded,
# Nearest to something: conant, polite, nonconfirmative, aptly, couldn, say, hypnotist, charger,
# Nearest to additional: block, separately, synoptic, mingw, vires, header, stjepan, insufflated,
# Nearest to report: recommends, della, conclusions, headline, reviewed, diagnostic, inscription, arrested,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8144 0.9198 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8619 0.9181 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8141 0.9062 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8769 0.9217 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8521 0.9182 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8532 0.9159 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8561 0.6733 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8447 0.8764 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8177 0.8703 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8498 0.8923 sec/batch
# Nearest to see: links, also, of, disambiguation, article, external, on, updated,
# Nearest to d: gairy, b, harold, poet, teton, boole, hess, alphonse,
# Nearest to between: schematic, finally, at, four, newt, distinction, the, other,
# Nearest to who: upu, trifling, troop, amicable, addressee, to, hisham, jesse,
# Nearest to known: as, with, most, that, many, by, in, the,
# Nearest to no: import, anthropologist, simms, calendrical, micah, uncooked, yes, willoughby,
# Nearest to also: a, of, the, in, is, see, has, with,
# Nearest to th: century, leap, on, remainder, molson, albemarle, nd, decline,
# Nearest to road: roads, highways, ballad, brick, ride, retaking, unpaved, maradns,
# Nearest to pressure: narrowing, msrp, vorticity, reversibility, secretive, joule, deportivo, detonator,
# Nearest to writers: fiction, novelists, illustrators, poets, births, autodidacts, alumni, essayists,
# Nearest to award: awarded, best, awards, academy, emmy, medal, outstanding, nominations,
# Nearest to recorded: recording, lp, live, cabrera, record, transfered, monticello, shortlist,
# Nearest to something: conant, couldn, say, nonconfirmative, aptly, polite, hypnotist, charger,
# Nearest to additional: block, mingw, separately, synoptic, vires, header, ballplayers, insufflated,
# Nearest to report: recommends, headline, della, conclusions, reviewed, diagnostic, inscription, locksmith,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7950 0.8719 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8158 0.8670 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7697 0.8671 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8825 0.8599 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8308 0.8670 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8639 0.8690 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8689 0.8739 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7386 0.9103 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8229 0.9273 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7991 0.9606 sec/batch
# Nearest to see: of, also, links, article, disambiguation, on, external, a,
# Nearest to d: gairy, teton, swains, avro, harold, boole, audit, cap,
# Nearest to between: other, of, at, four, the, than, schematic, distinction,
# Nearest to who: upu, troop, trifling, balkline, jesse, amicable, addressee, hisham,
# Nearest to known: as, that, most, many, with, in, by, and,
# Nearest to no: import, anthropologist, simms, calendrical, yes, micah, eight, clausewitz,
# Nearest to also: of, the, a, in, see, is, has, with,
# Nearest to th: century, leap, remainder, decline, on, mid, albemarle, late,
# Nearest to road: roads, highways, brick, ballad, kvac, ride, unpaved, bikes,
# Nearest to pressure: reversibility, vorticity, narrowing, msrp, secretive, joule, detonator, deportivo,
# Nearest to writers: fiction, novelists, illustrators, poets, births, autodidacts, essayists, alumni,
# Nearest to award: awarded, awards, best, emmy, medal, academy, outstanding, preclear,
# Nearest to recorded: recording, lp, highest, live, record, cabrera, transfered, shortlist,
# Nearest to something: conant, nonconfirmative, say, aptly, couldn, charger, subscript, polite,
# Nearest to additional: block, mingw, vires, synoptic, separately, header, pass, iter,
# Nearest to report: conclusions, recommends, della, reviewed, headline, diagnostic, inscription, april,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.8052 0.9433 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8217 0.9214 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8388 0.9272 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8003 0.9372 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8388 0.9443 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9043 0.9326 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8124 0.9285 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8328 0.8776 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8541 0.8799 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8467 0.9108 sec/batch
# Nearest to see: also, links, of, article, disambiguation, external, in, on,
# Nearest to d: gairy, harold, teton, toonopedia, tta, audit, boole, cap,
# Nearest to between: other, of, at, distinction, schematic, four, finally, there,
# Nearest to who: upu, trifling, polly, addressee, troop, balkline, hisham, eponym,
# Nearest to known: as, that, most, many, with, in, by, the,
# Nearest to no: anthropologist, import, simms, calendrical, eight, yes, clausewitz, empress,
# Nearest to also: a, of, the, see, is, in, for, has,
# Nearest to th: century, leap, mid, decline, albemarle, remainder, nd, molson,
# Nearest to road: roads, highways, brick, ballad, jessie, ride, maradns, unpaved,
# Nearest to pressure: vorticity, joule, reversibility, narrowing, msrp, exerts, secretive, deportivo,
# Nearest to writers: fiction, novelists, poets, illustrators, autodidacts, screenwriters, births, essayists,
# Nearest to award: awarded, awards, best, emmy, academy, medal, outstanding, critically,
# Nearest to recorded: recording, lp, live, record, lauded, cabrera, knitters, shortlist,
# Nearest to something: conant, say, nonconfirmative, couldn, aptly, subscript, polite, arrive,
# Nearest to additional: block, separately, vires, synoptic, mingw, pass, header, hemisphere,
# Nearest to report: recommends, conclusions, della, reviewed, headline, diagnostic, locksmith, detained,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8400 1.0131 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8349 0.9964 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8516 1.0125 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8332 0.9784 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8689 1.0005 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8203 0.9673 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8500 0.9072 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8103 0.9336 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8166 0.9667 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8059 0.9470 sec/batch
# Nearest to see: links, of, also, article, external, in, a, on,
# Nearest to d: teton, audit, tta, gairy, cap, harold, overthrown, swains,
# Nearest to between: four, other, of, the, at, newt, over, distinction,
# Nearest to who: upu, hisham, trifling, to, troop, amicable, ethiopians, living,
# Nearest to known: as, most, that, with, many, by, in, the,
# Nearest to no: import, simms, anthropologist, eight, calendrical, insubstantial, clausewitz, yes,
# Nearest to also: a, the, of, is, see, in, for, has,
# Nearest to th: century, decline, remainder, leap, late, mid, nd, albemarle,
# Nearest to road: roads, highways, ballad, brick, jessie, unpaved, maradns, retaking,
# Nearest to pressure: joule, vorticity, reversibility, msrp, narrowing, deportivo, secretive, detonator,
# Nearest to writers: fiction, novelists, poets, illustrators, authors, autodidacts, births, screenwriters,
# Nearest to award: awarded, awards, best, emmy, outstanding, medal, academy, critically,
# Nearest to recorded: recording, lp, record, lauded, cabrera, transfered, knitters, live,
# Nearest to something: conant, couldn, say, nonconfirmative, polite, charger, aptly, hypnotist,
# Nearest to additional: block, separately, synoptic, mingw, vires, pass, header, hemisphere,
# Nearest to report: recommends, della, conclusions, reviewed, headline, diagnostic, inscription, april,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8508 0.9655 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8185 0.9944 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9265 0.9589 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8867 1.0002 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9131 1.0415 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8047 1.0216 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7767 1.0302 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8359 0.9971 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7621 0.9260 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8678 0.9172 sec/batch
# Nearest to see: of, links, also, article, a, external, updated, on,
# Nearest to d: b, gairy, poet, teton, cyr, alphonse, harold, one,
# Nearest to between: of, the, four, over, other, newt, finally, at,
# Nearest to who: upu, troop, hisham, amicable, jesse, trifling, balkline, amu,
# Nearest to known: as, most, that, with, many, by, the, in,
# Nearest to no: import, simms, anthropologist, yes, calendrical, eight, uncooked, clausewitz,
# Nearest to also: a, the, of, in, is, see, for, an,
# Nearest to th: century, leap, nd, remainder, molson, mid, late, albemarle,
# Nearest to road: roads, highways, ballad, brick, jessie, retaking, maradns, unpaved,
# Nearest to pressure: vorticity, joule, reversibility, narrowing, msrp, secretive, deportivo, detonator,
# Nearest to writers: fiction, novelists, poets, illustrators, authors, autodidacts, alumni, screenwriters,
# Nearest to award: awarded, best, awards, outstanding, emmy, medal, academy, critically,
# Nearest to recorded: recording, live, lp, record, lauded, cabrera, shortlist, knitters,
# Nearest to something: conant, say, couldn, nonconfirmative, polite, aptly, conversation, hypnotist,
# Nearest to additional: block, separately, vires, synoptic, mingw, header, pass, iter,
# Nearest to report: della, conclusions, recommends, reviewed, headline, inscription, diagnostic, april,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8175 0.9207 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8354 0.9743 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding_var)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
