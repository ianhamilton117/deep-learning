# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = [[source_vocab_to_int[word] for word in line.split()] for line in source_text.split('\n')]
    target_id_text = [[target_vocab_to_int[word] for word in line.split()] + [target_vocab_to_int['<EOS>']] for line in target_text.split('\n')]
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    input = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    learn_rate = tf.placeholder(tf.float32, name='learn_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    return input, targets, learn_rate, keep_prob

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    enc_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)
    _, enc_state = tf.nn.dynamic_rnn(enc_cell, rnn_inputs, dtype=tf.float32)
    return enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    # Training Decoder
    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(
        dec_cell, train_decoder_fn, dec_embed_input, sequence_length, scope=decoding_scope)
    
    # Apply output function
    train_logits =  output_fn(train_pred)
    
    return train_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
        output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, 
        maximum_length - 1, vocab_size)
    inference_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    return inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    
    # Decoder RNNs
    dec_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)
    
    with tf.variable_scope("decoding") as decoding_scope:
        # Output Layer
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
        
        training_logits = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, 
                                               decoding_scope, output_fn, keep_prob)
        decoding_scope.reuse_variables()
        inference_logits = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>'], 
                                                sequence_length, vocab_size, decoding_scope, output_fn, keep_prob)
    return training_logits, inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # Encoder embedding
    enc_embed_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)

    encoder_state = encoding_layer(enc_embed_input, rnn_size, num_layers, keep_prob)
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    
    # Decoder Embedding
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    return decoding_layer(dec_embed_input, dec_embeddings, encoder_state, target_vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 100
# Batch Size
batch_size = 1024
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 13
decoding_embedding_size = 13
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.5

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/134 - Train Accuracy:  0.213, Validation Accuracy:  0.255, Loss:  5.891
# Epoch   0 Batch    1/134 - Train Accuracy:  0.195, Validation Accuracy:  0.271, Loss:  5.865
# Epoch   0 Batch    2/134 - Train Accuracy:  0.269, Validation Accuracy:  0.304, Loss:  5.838
# Epoch   0 Batch    3/134 - Train Accuracy:  0.278, Validation Accuracy:  0.312, Loss:  5.810
# Epoch   0 Batch    4/134 - Train Accuracy:  0.268, Validation Accuracy:  0.310, Loss:  5.780
# Epoch   0 Batch    5/134 - Train Accuracy:  0.276, Validation Accuracy:  0.310, Loss:  5.743
# Epoch   0 Batch    6/134 - Train Accuracy:  0.307, Validation Accuracy:  0.310, Loss:  5.685
# Epoch   0 Batch    7/134 - Train Accuracy:  0.268, Validation Accuracy:  0.310, Loss:  5.656
# Epoch   0 Batch    8/134 - Train Accuracy:  0.269, Validation Accuracy:  0.310, Loss:  5.599
# Epoch   0 Batch    9/134 - Train Accuracy:  0.307, Validation Accuracy:  0.310, Loss:  5.498
# Epoch   0 Batch   10/134 - Train Accuracy:  0.278, Validation Accuracy:  0.310, Loss:  5.457
# Epoch   0 Batch   11/134 - Train Accuracy:  0.282, Validation Accuracy:  0.310, Loss:  5.378
# Epoch   0 Batch   12/134 - Train Accuracy:  0.311, Validation Accuracy:  0.310, Loss:  5.258
# Epoch   0 Batch   13/134 - Train Accuracy:  0.266, Validation Accuracy:  0.310, Loss:  5.241
# Epoch   0 Batch   14/134 - Train Accuracy:  0.268, Validation Accuracy:  0.310, Loss:  5.162
# Epoch   0 Batch   15/134 - Train Accuracy:  0.275, Validation Accuracy:  0.310, Loss:  5.079
# Epoch   0 Batch   16/134 - Train Accuracy:  0.276, Validation Accuracy:  0.310, Loss:  4.998
# Epoch   0 Batch   17/134 - Train Accuracy:  0.276, Validation Accuracy:  0.310, Loss:  4.926
# Epoch   0 Batch   18/134 - Train Accuracy:  0.276, Validation Accuracy:  0.310, Loss:  4.849
# Epoch   0 Batch   19/134 - Train Accuracy:  0.273, Validation Accuracy:  0.310, Loss:  4.775
# Epoch   0 Batch   20/134 - Train Accuracy:  0.305, Validation Accuracy:  0.310, Loss:  4.630
# Epoch   0 Batch   21/134 - Train Accuracy:  0.284, Validation Accuracy:  0.310, Loss:  4.605
# Epoch   0 Batch   22/134 - Train Accuracy:  0.235, Validation Accuracy:  0.310, Loss:  4.627
# Epoch   0 Batch   23/134 - Train Accuracy:  0.309, Validation Accuracy:  0.310, Loss:  4.389
# Epoch   0 Batch   24/134 - Train Accuracy:  0.246, Validation Accuracy:  0.310, Loss:  4.469
# Epoch   0 Batch   25/134 - Train Accuracy:  0.273, Validation Accuracy:  0.310, Loss:  4.331
# Epoch   0 Batch   26/134 - Train Accuracy:  0.243, Validation Accuracy:  0.310, Loss:  4.339
# Epoch   0 Batch   27/134 - Train Accuracy:  0.278, Validation Accuracy:  0.310, Loss:  4.187
# Epoch   0 Batch   28/134 - Train Accuracy:  0.278, Validation Accuracy:  0.310, Loss:  4.123
# Epoch   0 Batch   29/134 - Train Accuracy:  0.300, Validation Accuracy:  0.310, Loss:  3.994
# Epoch   0 Batch   30/134 - Train Accuracy:  0.307, Validation Accuracy:  0.310, Loss:  3.924
# Epoch   0 Batch   31/134 - Train Accuracy:  0.273, Validation Accuracy:  0.310, Loss:  3.956
# Epoch   0 Batch   32/134 - Train Accuracy:  0.303, Validation Accuracy:  0.310, Loss:  3.816
# Epoch   0 Batch   33/134 - Train Accuracy:  0.275, Validation Accuracy:  0.310, Loss:  3.861
# Epoch   0 Batch   34/134 - Train Accuracy:  0.279, Validation Accuracy:  0.310, Loss:  3.800
# Epoch   0 Batch   35/134 - Train Accuracy:  0.308, Validation Accuracy:  0.310, Loss:  3.679
# Epoch   0 Batch   36/134 - Train Accuracy:  0.280, Validation Accuracy:  0.310, Loss:  3.725
# Epoch   0 Batch   37/134 - Train Accuracy:  0.267, Validation Accuracy:  0.310, Loss:  3.720
# Epoch   0 Batch   38/134 - Train Accuracy:  0.275, Validation Accuracy:  0.310, Loss:  3.671
# Epoch   0 Batch   39/134 - Train Accuracy:  0.278, Validation Accuracy:  0.310, Loss:  3.630
# Epoch   0 Batch   40/134 - Train Accuracy:  0.281, Validation Accuracy:  0.310, Loss:  3.605
# Epoch   0 Batch   41/134 - Train Accuracy:  0.278, Validation Accuracy:  0.310, Loss:  3.577
# Epoch   0 Batch   42/134 - Train Accuracy:  0.267, Validation Accuracy:  0.310, Loss:  3.592
# Epoch   0 Batch   43/134 - Train Accuracy:  0.293, Validation Accuracy:  0.328, Loss:  3.562
# Epoch   0 Batch   44/134 - Train Accuracy:  0.307, Validation Accuracy:  0.341, Loss:  3.534
# Epoch   0 Batch   45/134 - Train Accuracy:  0.310, Validation Accuracy:  0.341, Loss:  3.506
# Epoch   0 Batch   46/134 - Train Accuracy:  0.341, Validation Accuracy:  0.342, Loss:  3.390
# Epoch   0 Batch   47/134 - Train Accuracy:  0.309, Validation Accuracy:  0.342, Loss:  3.485
# Epoch   0 Batch   48/134 - Train Accuracy:  0.315, Validation Accuracy:  0.342, Loss:  3.452
# Epoch   0 Batch   49/134 - Train Accuracy:  0.315, Validation Accuracy:  0.342, Loss:  3.435
# Epoch   0 Batch   50/134 - Train Accuracy:  0.310, Validation Accuracy:  0.342, Loss:  3.444
# Epoch   0 Batch   51/134 - Train Accuracy:  0.311, Validation Accuracy:  0.342, Loss:  3.435
# Epoch   0 Batch   52/134 - Train Accuracy:  0.307, Validation Accuracy:  0.342, Loss:  3.431
# Epoch   0 Batch   53/134 - Train Accuracy:  0.301, Validation Accuracy:  0.342, Loss:  3.435
# Epoch   0 Batch   54/134 - Train Accuracy:  0.308, Validation Accuracy:  0.342, Loss:  3.414
# Epoch   0 Batch   55/134 - Train Accuracy:  0.310, Validation Accuracy:  0.342, Loss:  3.400
# Epoch   0 Batch   56/134 - Train Accuracy:  0.340, Validation Accuracy:  0.342, Loss:  3.273
# Epoch   0 Batch   57/134 - Train Accuracy:  0.309, Validation Accuracy:  0.342, Loss:  3.367
# Epoch   0 Batch   58/134 - Train Accuracy:  0.307, Validation Accuracy:  0.341, Loss:  3.351
# Epoch   0 Batch   59/134 - Train Accuracy:  0.277, Validation Accuracy:  0.341, Loss:  3.479
# Epoch   0 Batch   60/134 - Train Accuracy:  0.311, Validation Accuracy:  0.341, Loss:  3.341
# Epoch   0 Batch   61/134 - Train Accuracy:  0.303, Validation Accuracy:  0.341, Loss:  3.343
# Epoch   0 Batch   62/134 - Train Accuracy:  0.308, Validation Accuracy:  0.341, Loss:  3.318
# Epoch   0 Batch   63/134 - Train Accuracy:  0.312, Validation Accuracy:  0.341, Loss:  3.310
# Epoch   0 Batch   64/134 - Train Accuracy:  0.306, Validation Accuracy:  0.342, Loss:  3.330
# Epoch   0 Batch   65/134 - Train Accuracy:  0.309, Validation Accuracy:  0.342, Loss:  3.304
# Epoch   0 Batch   66/134 - Train Accuracy:  0.308, Validation Accuracy:  0.342, Loss:  3.290
# Epoch   0 Batch   67/134 - Train Accuracy:  0.270, Validation Accuracy:  0.343, Loss:  3.443
# Epoch   0 Batch   68/134 - Train Accuracy:  0.277, Validation Accuracy:  0.343, Loss:  3.398
# Epoch   0 Batch   69/134 - Train Accuracy:  0.311, Validation Accuracy:  0.343, Loss:  3.263
# Epoch   0 Batch   70/134 - Train Accuracy:  0.314, Validation Accuracy:  0.343, Loss:  3.248
# Epoch   0 Batch   71/134 - Train Accuracy:  0.309, Validation Accuracy:  0.343, Loss:  3.260
# Epoch   0 Batch   72/134 - Train Accuracy:  0.307, Validation Accuracy:  0.343, Loss:  3.260
# Epoch   0 Batch   73/134 - Train Accuracy:  0.340, Validation Accuracy:  0.343, Loss:  3.137
# Epoch   0 Batch   74/134 - Train Accuracy:  0.314, Validation Accuracy:  0.343, Loss:  3.234
# Epoch   0 Batch   75/134 - Train Accuracy:  0.341, Validation Accuracy:  0.343, Loss:  3.109
# Epoch   0 Batch   76/134 - Train Accuracy:  0.303, Validation Accuracy:  0.343, Loss:  3.227
# Epoch   0 Batch   77/134 - Train Accuracy:  0.346, Validation Accuracy:  0.343, Loss:  3.062
# Epoch   0 Batch   78/134 - Train Accuracy:  0.307, Validation Accuracy:  0.343, Loss:  3.189
# Epoch   0 Batch   79/134 - Train Accuracy:  0.310, Validation Accuracy:  0.343, Loss:  3.190
# Epoch   0 Batch   80/134 - Train Accuracy:  0.306, Validation Accuracy:  0.343, Loss:  3.197
# Epoch   0 Batch   81/134 - Train Accuracy:  0.308, Validation Accuracy:  0.343, Loss:  3.179
# Epoch   0 Batch   82/134 - Train Accuracy:  0.342, Validation Accuracy:  0.343, Loss:  3.038
# Epoch   0 Batch   83/134 - Train Accuracy:  0.310, Validation Accuracy:  0.343, Loss:  3.167
# Epoch   0 Batch   84/134 - Train Accuracy:  0.307, Validation Accuracy:  0.343, Loss:  3.162
# Epoch   0 Batch   85/134 - Train Accuracy:  0.311, Validation Accuracy:  0.343, Loss:  3.146
# Epoch   0 Batch   86/134 - Train Accuracy:  0.307, Validation Accuracy:  0.343, Loss:  3.149
# Epoch   0 Batch   87/134 - Train Accuracy:  0.307, Validation Accuracy:  0.343, Loss:  3.150
# Epoch   0 Batch   88/134 - Train Accuracy:  0.338, Validation Accuracy:  0.343, Loss:  3.024
# Epoch   0 Batch   89/134 - Train Accuracy:  0.309, Validation Accuracy:  0.343, Loss:  3.136
# Epoch   0 Batch   90/134 - Train Accuracy:  0.315, Validation Accuracy:  0.343, Loss:  3.119
# Epoch   0 Batch   91/134 - Train Accuracy:  0.392, Validation Accuracy:  0.343, Loss:  2.790
# Epoch   0 Batch   92/134 - Train Accuracy:  0.316, Validation Accuracy:  0.343, Loss:  3.091
# Epoch   0 Batch   93/134 - Train Accuracy:  0.320, Validation Accuracy:  0.343, Loss:  3.071
# Epoch   0 Batch   94/134 - Train Accuracy:  0.314, Validation Accuracy:  0.343, Loss:  3.084
# Epoch   0 Batch   95/134 - Train Accuracy:  0.309, Validation Accuracy:  0.343, Loss:  3.103
# Epoch   0 Batch   96/134 - Train Accuracy:  0.309, Validation Accuracy:  0.343, Loss:  3.098
# Epoch   0 Batch   97/134 - Train Accuracy:  0.306, Validation Accuracy:  0.343, Loss:  3.103
# Epoch   0 Batch   98/134 - Train Accuracy:  0.273, Validation Accuracy:  0.343, Loss:  3.221
# Epoch   0 Batch   99/134 - Train Accuracy:  0.310, Validation Accuracy:  0.343, Loss:  3.078
# Epoch   0 Batch  100/134 - Train Accuracy:  0.308, Validation Accuracy:  0.343, Loss:  3.082
# Epoch   0 Batch  101/134 - Train Accuracy:  0.281, Validation Accuracy:  0.343, Loss:  3.186
# Epoch   0 Batch  102/134 - Train Accuracy:  0.309, Validation Accuracy:  0.343, Loss:  3.071
# Epoch   0 Batch  103/134 - Train Accuracy:  0.341, Validation Accuracy:  0.343, Loss:  2.955
# Epoch   0 Batch  104/134 - Train Accuracy:  0.311, Validation Accuracy:  0.343, Loss:  3.046
# Epoch   0 Batch  105/134 - Train Accuracy:  0.317, Validation Accuracy:  0.343, Loss:  3.028
# Epoch   0 Batch  106/134 - Train Accuracy:  0.311, Validation Accuracy:  0.343, Loss:  3.035
# Epoch   0 Batch  107/134 - Train Accuracy:  0.348, Validation Accuracy:  0.343, Loss:  2.909
# Epoch   0 Batch  108/134 - Train Accuracy:  0.276, Validation Accuracy:  0.343, Loss:  3.169
# Epoch   0 Batch  109/134 - Train Accuracy:  0.340, Validation Accuracy:  0.343, Loss:  2.920
# Epoch   0 Batch  110/134 - Train Accuracy:  0.316, Validation Accuracy:  0.343, Loss:  2.998
# Epoch   0 Batch  111/134 - Train Accuracy:  0.314, Validation Accuracy:  0.343, Loss:  3.010
# Epoch   0 Batch  112/134 - Train Accuracy:  0.315, Validation Accuracy:  0.343, Loss:  3.018
# Epoch   0 Batch  113/134 - Train Accuracy:  0.399, Validation Accuracy:  0.343, Loss:  2.695
# Epoch   0 Batch  114/134 - Train Accuracy:  0.311, Validation Accuracy:  0.343, Loss:  3.010
# Epoch   0 Batch  115/134 - Train Accuracy:  0.272, Validation Accuracy:  0.343, Loss:  3.145
# Epoch   0 Batch  116/134 - Train Accuracy:  0.308, Validation Accuracy:  0.343, Loss:  3.019
# Epoch   0 Batch  117/134 - Train Accuracy:  0.311, Validation Accuracy:  0.343, Loss:  3.002
# Epoch   0 Batch  118/134 - Train Accuracy:  0.314, Validation Accuracy:  0.343, Loss:  2.993
# Epoch   0 Batch  119/134 - Train Accuracy:  0.368, Validation Accuracy:  0.343, Loss:  2.782
# Epoch   0 Batch  120/134 - Train Accuracy:  0.311, Validation Accuracy:  0.343, Loss:  2.996
# Epoch   0 Batch  121/134 - Train Accuracy:  0.315, Validation Accuracy:  0.343, Loss:  2.964
# Epoch   0 Batch  122/134 - Train Accuracy:  0.312, Validation Accuracy:  0.343, Loss:  2.987
# Epoch   0 Batch  123/134 - Train Accuracy:  0.313, Validation Accuracy:  0.343, Loss:  2.978
# Epoch   0 Batch  124/134 - Train Accuracy:  0.346, Validation Accuracy:  0.343, Loss:  2.853
# Epoch   0 Batch  125/134 - Train Accuracy:  0.304, Validation Accuracy:  0.343, Loss:  2.994
# Epoch   0 Batch  126/134 - Train Accuracy:  0.309, Validation Accuracy:  0.343, Loss:  2.967
# Epoch   0 Batch  127/134 - Train Accuracy:  0.334, Validation Accuracy:  0.343, Loss:  2.881
# Epoch   0 Batch  128/134 - Train Accuracy:  0.309, Validation Accuracy:  0.343, Loss:  2.974
# Epoch   0 Batch  129/134 - Train Accuracy:  0.314, Validation Accuracy:  0.344, Loss:  2.958
# Epoch   0 Batch  130/134 - Train Accuracy:  0.307, Validation Accuracy:  0.345, Loss:  2.979
# Epoch   0 Batch  131/134 - Train Accuracy:  0.286, Validation Accuracy:  0.345, Loss:  3.069
# Epoch   0 Batch  132/134 - Train Accuracy:  0.315, Validation Accuracy:  0.349, Loss:  2.942
# Epoch   1 Batch    0/134 - Train Accuracy:  0.314, Validation Accuracy:  0.354, Loss:  2.969
# Epoch   1 Batch    1/134 - Train Accuracy:  0.292, Validation Accuracy:  0.359, Loss:  3.079
# Epoch   1 Batch    2/134 - Train Accuracy:  0.330, Validation Accuracy:  0.363, Loss:  2.940
# Epoch   1 Batch    3/134 - Train Accuracy:  0.335, Validation Accuracy:  0.366, Loss:  2.929
# Epoch   1 Batch    4/134 - Train Accuracy:  0.329, Validation Accuracy:  0.366, Loss:  2.937
# Epoch   1 Batch    5/134 - Train Accuracy:  0.336, Validation Accuracy:  0.368, Loss:  2.929
# Epoch   1 Batch    6/134 - Train Accuracy:  0.365, Validation Accuracy:  0.368, Loss:  2.805
# Epoch   1 Batch    7/134 - Train Accuracy:  0.330, Validation Accuracy:  0.367, Loss:  2.942
# Epoch   1 Batch    8/134 - Train Accuracy:  0.333, Validation Accuracy:  0.370, Loss:  2.925
# Epoch   1 Batch    9/134 - Train Accuracy:  0.369, Validation Accuracy:  0.370, Loss:  2.789
# Epoch   1 Batch   10/134 - Train Accuracy:  0.342, Validation Accuracy:  0.369, Loss:  2.907
# Epoch   1 Batch   11/134 - Train Accuracy:  0.346, Validation Accuracy:  0.372, Loss:  2.897
# Epoch   1 Batch   12/134 - Train Accuracy:  0.371, Validation Accuracy:  0.371, Loss:  2.783
# Epoch   1 Batch   13/134 - Train Accuracy:  0.331, Validation Accuracy:  0.370, Loss:  2.930
# Epoch   1 Batch   14/134 - Train Accuracy:  0.334, Validation Accuracy:  0.370, Loss:  2.908
# Epoch   1 Batch   15/134 - Train Accuracy:  0.337, Validation Accuracy:  0.371, Loss:  2.910
# Epoch   1 Batch   16/134 - Train Accuracy:  0.336, Validation Accuracy:  0.367, Loss:  2.874
# Epoch   1 Batch   17/134 - Train Accuracy:  0.336, Validation Accuracy:  0.367, Loss:  2.885
# Epoch   1 Batch   18/134 - Train Accuracy:  0.336, Validation Accuracy:  0.367, Loss:  2.888
# Epoch   1 Batch   19/134 - Train Accuracy:  0.333, Validation Accuracy:  0.366, Loss:  2.875
# Epoch   1 Batch   20/134 - Train Accuracy:  0.361, Validation Accuracy:  0.365, Loss:  2.765
# Epoch   1 Batch   21/134 - Train Accuracy:  0.338, Validation Accuracy:  0.365, Loss:  2.858
# Epoch   1 Batch   22/134 - Train Accuracy:  0.293, Validation Accuracy:  0.361, Loss:  3.004
# Epoch   1 Batch   23/134 - Train Accuracy:  0.358, Validation Accuracy:  0.360, Loss:  2.732
# Epoch   1 Batch   24/134 - Train Accuracy:  0.297, Validation Accuracy:  0.358, Loss:  2.972
# Epoch   1 Batch   25/134 - Train Accuracy:  0.317, Validation Accuracy:  0.353, Loss:  2.866
# Epoch   1 Batch   26/134 - Train Accuracy:  0.288, Validation Accuracy:  0.352, Loss:  2.976
# Epoch   1 Batch   27/134 - Train Accuracy:  0.320, Validation Accuracy:  0.351, Loss:  2.844
# Epoch   1 Batch   28/134 - Train Accuracy:  0.318, Validation Accuracy:  0.349, Loss:  2.848
# Epoch   1 Batch   29/134 - Train Accuracy:  0.339, Validation Accuracy:  0.348, Loss:  2.741
# Epoch   1 Batch   30/134 - Train Accuracy:  0.344, Validation Accuracy:  0.348, Loss:  2.731
# Epoch   1 Batch   31/134 - Train Accuracy:  0.312, Validation Accuracy:  0.348, Loss:  2.835
# Epoch   1 Batch   32/134 - Train Accuracy:  0.342, Validation Accuracy:  0.348, Loss:  2.725
# Epoch   1 Batch   33/134 - Train Accuracy:  0.315, Validation Accuracy:  0.348, Loss:  2.837
# Epoch   1 Batch   34/134 - Train Accuracy:  0.323, Validation Accuracy:  0.351, Loss:  2.823
# Epoch   1 Batch   35/134 - Train Accuracy:  0.350, Validation Accuracy:  0.352, Loss:  2.715
# Epoch   1 Batch   36/134 - Train Accuracy:  0.320, Validation Accuracy:  0.351, Loss:  2.803
# Epoch   1 Batch   37/134 - Train Accuracy:  0.311, Validation Accuracy:  0.352, Loss:  2.836
# Epoch   1 Batch   38/134 - Train Accuracy:  0.320, Validation Accuracy:  0.353, Loss:  2.811
# Epoch   1 Batch   39/134 - Train Accuracy:  0.322, Validation Accuracy:  0.354, Loss:  2.792
# Epoch   1 Batch   40/134 - Train Accuracy:  0.325, Validation Accuracy:  0.354, Loss:  2.791
# Epoch   1 Batch   41/134 - Train Accuracy:  0.326, Validation Accuracy:  0.355, Loss:  2.777
# Epoch   1 Batch   42/134 - Train Accuracy:  0.314, Validation Accuracy:  0.356, Loss:  2.819
# Epoch   1 Batch   43/134 - Train Accuracy:  0.322, Validation Accuracy:  0.357, Loss:  2.810
# Epoch   1 Batch   44/134 - Train Accuracy:  0.329, Validation Accuracy:  0.364, Loss:  2.788
# Epoch   1 Batch   45/134 - Train Accuracy:  0.332, Validation Accuracy:  0.365, Loss:  2.776
# Epoch   1 Batch   46/134 - Train Accuracy:  0.364, Validation Accuracy:  0.367, Loss:  2.673
# Epoch   1 Batch   47/134 - Train Accuracy:  0.335, Validation Accuracy:  0.369, Loss:  2.774
# Epoch   1 Batch   48/134 - Train Accuracy:  0.342, Validation Accuracy:  0.368, Loss:  2.755
# Epoch   1 Batch   49/134 - Train Accuracy:  0.345, Validation Accuracy:  0.372, Loss:  2.742
# Epoch   1 Batch   50/134 - Train Accuracy:  0.340, Validation Accuracy:  0.372, Loss:  2.762
# Epoch   1 Batch   51/134 - Train Accuracy:  0.339, Validation Accuracy:  0.372, Loss:  2.759
# Epoch   1 Batch   52/134 - Train Accuracy:  0.337, Validation Accuracy:  0.373, Loss:  2.771
# Epoch   1 Batch   53/134 - Train Accuracy:  0.333, Validation Accuracy:  0.374, Loss:  2.775
# Epoch   1 Batch   54/134 - Train Accuracy:  0.339, Validation Accuracy:  0.373, Loss:  2.758
# Epoch   1 Batch   55/134 - Train Accuracy:  0.341, Validation Accuracy:  0.376, Loss:  2.756
# Epoch   1 Batch   56/134 - Train Accuracy:  0.374, Validation Accuracy:  0.378, Loss:  2.631
# Epoch   1 Batch   57/134 - Train Accuracy:  0.344, Validation Accuracy:  0.378, Loss:  2.735
# Epoch   1 Batch   58/134 - Train Accuracy:  0.346, Validation Accuracy:  0.377, Loss:  2.718
# Epoch   1 Batch   59/134 - Train Accuracy:  0.316, Validation Accuracy:  0.377, Loss:  2.846
# Epoch   1 Batch   60/134 - Train Accuracy:  0.346, Validation Accuracy:  0.375, Loss:  2.713
# Epoch   1 Batch   61/134 - Train Accuracy:  0.337, Validation Accuracy:  0.376, Loss:  2.732
# Epoch   1 Batch   62/134 - Train Accuracy:  0.340, Validation Accuracy:  0.374, Loss:  2.708
# Epoch   1 Batch   63/134 - Train Accuracy:  0.348, Validation Accuracy:  0.374, Loss:  2.704
# Epoch   1 Batch   64/134 - Train Accuracy:  0.337, Validation Accuracy:  0.374, Loss:  2.736
# Epoch   1 Batch   65/134 - Train Accuracy:  0.340, Validation Accuracy:  0.375, Loss:  2.712
# Epoch   1 Batch   66/134 - Train Accuracy:  0.339, Validation Accuracy:  0.374, Loss:  2.695
# Epoch   1 Batch   67/134 - Train Accuracy:  0.302, Validation Accuracy:  0.376, Loss:  2.858
# Epoch   1 Batch   68/134 - Train Accuracy:  0.311, Validation Accuracy:  0.374, Loss:  2.808
# Epoch   1 Batch   69/134 - Train Accuracy:  0.342, Validation Accuracy:  0.375, Loss:  2.684
# Epoch   1 Batch   70/134 - Train Accuracy:  0.348, Validation Accuracy:  0.375, Loss:  2.662
# Epoch   1 Batch   71/134 - Train Accuracy:  0.336, Validation Accuracy:  0.373, Loss:  2.692
# Epoch   1 Batch   72/134 - Train Accuracy:  0.338, Validation Accuracy:  0.373, Loss:  2.691
# Epoch   1 Batch   73/134 - Train Accuracy:  0.366, Validation Accuracy:  0.374, Loss:  2.593
# Epoch   1 Batch   74/134 - Train Accuracy:  0.344, Validation Accuracy:  0.372, Loss:  2.676
# Epoch   1 Batch   75/134 - Train Accuracy:  0.369, Validation Accuracy:  0.373, Loss:  2.572
# Epoch   1 Batch   76/134 - Train Accuracy:  0.334, Validation Accuracy:  0.376, Loss:  2.695
# Epoch   1 Batch   77/134 - Train Accuracy:  0.380, Validation Accuracy:  0.376, Loss:  2.533
# Epoch   1 Batch   78/134 - Train Accuracy:  0.340, Validation Accuracy:  0.378, Loss:  2.670
# Epoch   1 Batch   79/134 - Train Accuracy:  0.345, Validation Accuracy:  0.377, Loss:  2.667
# Epoch   1 Batch   80/134 - Train Accuracy:  0.338, Validation Accuracy:  0.377, Loss:  2.675
# Epoch   1 Batch   81/134 - Train Accuracy:  0.342, Validation Accuracy:  0.378, Loss:  2.660
# Epoch   1 Batch   82/134 - Train Accuracy:  0.379, Validation Accuracy:  0.379, Loss:  2.528
# Epoch   1 Batch   83/134 - Train Accuracy:  0.346, Validation Accuracy:  0.380, Loss:  2.654
# Epoch   1 Batch   84/134 - Train Accuracy:  0.345, Validation Accuracy:  0.382, Loss:  2.655
# Epoch   1 Batch   85/134 - Train Accuracy:  0.349, Validation Accuracy:  0.382, Loss:  2.638
# Epoch   1 Batch   86/134 - Train Accuracy:  0.348, Validation Accuracy:  0.383, Loss:  2.644
# Epoch   1 Batch   87/134 - Train Accuracy:  0.349, Validation Accuracy:  0.384, Loss:  2.647
# Epoch   1 Batch   88/134 - Train Accuracy:  0.379, Validation Accuracy:  0.385, Loss:  2.530
# Epoch   1 Batch   89/134 - Train Accuracy:  0.351, Validation Accuracy:  0.386, Loss:  2.636
# Epoch   1 Batch   90/134 - Train Accuracy:  0.361, Validation Accuracy:  0.391, Loss:  2.625
# Epoch   1 Batch   91/134 - Train Accuracy:  0.438, Validation Accuracy:  0.394, Loss:  2.326
# Epoch   1 Batch   92/134 - Train Accuracy:  0.373, Validation Accuracy:  0.397, Loss:  2.595
# Epoch   1 Batch   93/134 - Train Accuracy:  0.379, Validation Accuracy:  0.400, Loss:  2.563
# Epoch   1 Batch   94/134 - Train Accuracy:  0.382, Validation Accuracy:  0.409, Loss:  2.594
# Epoch   1 Batch   95/134 - Train Accuracy:  0.389, Validation Accuracy:  0.419, Loss:  2.611
# Epoch   1 Batch   96/134 - Train Accuracy:  0.390, Validation Accuracy:  0.421, Loss:  2.617
# Epoch   1 Batch   97/134 - Train Accuracy:  0.386, Validation Accuracy:  0.421, Loss:  2.629
# Epoch   1 Batch   98/134 - Train Accuracy:  0.358, Validation Accuracy:  0.421, Loss:  2.747
# Epoch   1 Batch   99/134 - Train Accuracy:  0.385, Validation Accuracy:  0.415, Loss:  2.618
# Epoch   1 Batch  100/134 - Train Accuracy:  0.382, Validation Accuracy:  0.414, Loss:  2.614
# Epoch   1 Batch  101/134 - Train Accuracy:  0.363, Validation Accuracy:  0.419, Loss:  2.694
# Epoch   1 Batch  102/134 - Train Accuracy:  0.393, Validation Accuracy:  0.422, Loss:  2.612
# Epoch   1 Batch  103/134 - Train Accuracy:  0.420, Validation Accuracy:  0.425, Loss:  2.497
# Epoch   1 Batch  104/134 - Train Accuracy:  0.400, Validation Accuracy:  0.427, Loss:  2.572
# Epoch   1 Batch  105/134 - Train Accuracy:  0.399, Validation Accuracy:  0.423, Loss:  2.562
# Epoch   1 Batch  106/134 - Train Accuracy:  0.397, Validation Accuracy:  0.424, Loss:  2.564
# Epoch   1 Batch  107/134 - Train Accuracy:  0.432, Validation Accuracy:  0.431, Loss:  2.462
# Epoch   1 Batch  108/134 - Train Accuracy:  0.372, Validation Accuracy:  0.432, Loss:  2.698
# Epoch   1 Batch  109/134 - Train Accuracy:  0.428, Validation Accuracy:  0.428, Loss:  2.457
# Epoch   1 Batch  110/134 - Train Accuracy:  0.404, Validation Accuracy:  0.428, Loss:  2.538
# Epoch   1 Batch  111/134 - Train Accuracy:  0.402, Validation Accuracy:  0.427, Loss:  2.541
# Epoch   1 Batch  112/134 - Train Accuracy:  0.403, Validation Accuracy:  0.428, Loss:  2.548
# Epoch   1 Batch  113/134 - Train Accuracy:  0.479, Validation Accuracy:  0.433, Loss:  2.265
# Epoch   1 Batch  114/134 - Train Accuracy:  0.403, Validation Accuracy:  0.430, Loss:  2.556
# Epoch   1 Batch  115/134 - Train Accuracy:  0.365, Validation Accuracy:  0.428, Loss:  2.684
# Epoch   1 Batch  116/134 - Train Accuracy:  0.397, Validation Accuracy:  0.429, Loss:  2.574
# Epoch   1 Batch  117/134 - Train Accuracy:  0.403, Validation Accuracy:  0.430, Loss:  2.548
# Epoch   1 Batch  118/134 - Train Accuracy:  0.405, Validation Accuracy:  0.431, Loss:  2.536
# Epoch   1 Batch  119/134 - Train Accuracy:  0.454, Validation Accuracy:  0.432, Loss:  2.347
# Epoch   1 Batch  120/134 - Train Accuracy:  0.405, Validation Accuracy:  0.432, Loss:  2.531
# Epoch   1 Batch  121/134 - Train Accuracy:  0.406, Validation Accuracy:  0.430, Loss:  2.516
# Epoch   1 Batch  122/134 - Train Accuracy:  0.403, Validation Accuracy:  0.432, Loss:  2.536
# Epoch   1 Batch  123/134 - Train Accuracy:  0.407, Validation Accuracy:  0.434, Loss:  2.525
# Epoch   1 Batch  124/134 - Train Accuracy:  0.438, Validation Accuracy:  0.435, Loss:  2.410
# Epoch   1 Batch  125/134 - Train Accuracy:  0.400, Validation Accuracy:  0.435, Loss:  2.554
# Epoch   1 Batch  126/134 - Train Accuracy:  0.406, Validation Accuracy:  0.435, Loss:  2.527
# Epoch   1 Batch  127/134 - Train Accuracy:  0.427, Validation Accuracy:  0.434, Loss:  2.450
# Epoch   1 Batch  128/134 - Train Accuracy:  0.402, Validation Accuracy:  0.435, Loss:  2.541
# Epoch   1 Batch  129/134 - Train Accuracy:  0.411, Validation Accuracy:  0.437, Loss:  2.510
# Epoch   1 Batch  130/134 - Train Accuracy:  0.406, Validation Accuracy:  0.442, Loss:  2.544
# Epoch   1 Batch  131/134 - Train Accuracy:  0.390, Validation Accuracy:  0.442, Loss:  2.619
# Epoch   1 Batch  132/134 - Train Accuracy:  0.413, Validation Accuracy:  0.441, Loss:  2.510
# Epoch   2 Batch    0/134 - Train Accuracy:  0.410, Validation Accuracy:  0.445, Loss:  2.534
# Epoch   2 Batch    1/134 - Train Accuracy:  0.387, Validation Accuracy:  0.445, Loss:  2.621
# Epoch   2 Batch    2/134 - Train Accuracy:  0.424, Validation Accuracy:  0.451, Loss:  2.499
# Epoch   2 Batch    3/134 - Train Accuracy:  0.424, Validation Accuracy:  0.451, Loss:  2.491
# Epoch   2 Batch    4/134 - Train Accuracy:  0.420, Validation Accuracy:  0.452, Loss:  2.501
# Epoch   2 Batch    5/134 - Train Accuracy:  0.426, Validation Accuracy:  0.453, Loss:  2.505
# Epoch   2 Batch    6/134 - Train Accuracy:  0.451, Validation Accuracy:  0.453, Loss:  2.380
# Epoch   2 Batch    7/134 - Train Accuracy:  0.420, Validation Accuracy:  0.452, Loss:  2.516
# Epoch   2 Batch    8/134 - Train Accuracy:  0.426, Validation Accuracy:  0.456, Loss:  2.491
# Epoch   2 Batch    9/134 - Train Accuracy:  0.456, Validation Accuracy:  0.454, Loss:  2.379
# Epoch   2 Batch   10/134 - Train Accuracy:  0.431, Validation Accuracy:  0.456, Loss:  2.492
# Epoch   2 Batch   11/134 - Train Accuracy:  0.435, Validation Accuracy:  0.459, Loss:  2.471
# Epoch   2 Batch   12/134 - Train Accuracy:  0.457, Validation Accuracy:  0.456, Loss:  2.368
# Epoch   2 Batch   13/134 - Train Accuracy:  0.414, Validation Accuracy:  0.455, Loss:  2.518
# Epoch   2 Batch   14/134 - Train Accuracy:  0.425, Validation Accuracy:  0.457, Loss:  2.491
# Epoch   2 Batch   15/134 - Train Accuracy:  0.426, Validation Accuracy:  0.454, Loss:  2.472
# Epoch   2 Batch   16/134 - Train Accuracy:  0.431, Validation Accuracy:  0.457, Loss:  2.459
# Epoch   2 Batch   17/134 - Train Accuracy:  0.435, Validation Accuracy:  0.462, Loss:  2.464
# Epoch   2 Batch   18/134 - Train Accuracy:  0.436, Validation Accuracy:  0.463, Loss:  2.478
# Epoch   2 Batch   19/134 - Train Accuracy:  0.432, Validation Accuracy:  0.462, Loss:  2.459
# Epoch   2 Batch   20/134 - Train Accuracy:  0.458, Validation Accuracy:  0.463, Loss:  2.369
# Epoch   2 Batch   21/134 - Train Accuracy:  0.440, Validation Accuracy:  0.462, Loss:  2.429
# Epoch   2 Batch   22/134 - Train Accuracy:  0.407, Validation Accuracy:  0.463, Loss:  2.583
# Epoch   2 Batch   23/134 - Train Accuracy:  0.466, Validation Accuracy:  0.465, Loss:  2.322
# Epoch   2 Batch   24/134 - Train Accuracy:  0.413, Validation Accuracy:  0.465, Loss:  2.543
# Epoch   2 Batch   25/134 - Train Accuracy:  0.437, Validation Accuracy:  0.465, Loss:  2.456
# Epoch   2 Batch   26/134 - Train Accuracy:  0.415, Validation Accuracy:  0.466, Loss:  2.549
# Epoch   2 Batch   27/134 - Train Accuracy:  0.440, Validation Accuracy:  0.468, Loss:  2.435
# Epoch   2 Batch   28/134 - Train Accuracy:  0.444, Validation Accuracy:  0.468, Loss:  2.438
# Epoch   2 Batch   29/134 - Train Accuracy:  0.459, Validation Accuracy:  0.468, Loss:  2.348
# Epoch   2 Batch   30/134 - Train Accuracy:  0.467, Validation Accuracy:  0.469, Loss:  2.337
# Epoch   2 Batch   31/134 - Train Accuracy:  0.442, Validation Accuracy:  0.469, Loss:  2.430
# Epoch   2 Batch   32/134 - Train Accuracy:  0.463, Validation Accuracy:  0.469, Loss:  2.343
# Epoch   2 Batch   33/134 - Train Accuracy:  0.437, Validation Accuracy:  0.468, Loss:  2.443
# Epoch   2 Batch   34/134 - Train Accuracy:  0.442, Validation Accuracy:  0.468, Loss:  2.439
# Epoch   2 Batch   35/134 - Train Accuracy:  0.464, Validation Accuracy:  0.469, Loss:  2.335
# Epoch   2 Batch   36/134 - Train Accuracy:  0.450, Validation Accuracy:  0.470, Loss:  2.402
# Epoch   2 Batch   37/134 - Train Accuracy:  0.431, Validation Accuracy:  0.467, Loss:  2.449
# Epoch   2 Batch   38/134 - Train Accuracy:  0.444, Validation Accuracy:  0.470, Loss:  2.432
# Epoch   2 Batch   39/134 - Train Accuracy:  0.442, Validation Accuracy:  0.468, Loss:  2.402
# Epoch   2 Batch   40/134 - Train Accuracy:  0.450, Validation Accuracy:  0.470, Loss:  2.400
# Epoch   2 Batch   41/134 - Train Accuracy:  0.445, Validation Accuracy:  0.472, Loss:  2.396
# Epoch   2 Batch   42/134 - Train Accuracy:  0.436, Validation Accuracy:  0.470, Loss:  2.431
# Epoch   2 Batch   43/134 - Train Accuracy:  0.442, Validation Accuracy:  0.470, Loss:  2.431
# Epoch   2 Batch   44/134 - Train Accuracy:  0.441, Validation Accuracy:  0.470, Loss:  2.413
# Epoch   2 Batch   45/134 - Train Accuracy:  0.444, Validation Accuracy:  0.470, Loss:  2.404
# Epoch   2 Batch   46/134 - Train Accuracy:  0.470, Validation Accuracy:  0.472, Loss:  2.316
# Epoch   2 Batch   47/134 - Train Accuracy:  0.445, Validation Accuracy:  0.471, Loss:  2.405
# Epoch   2 Batch   48/134 - Train Accuracy:  0.448, Validation Accuracy:  0.471, Loss:  2.383
# Epoch   2 Batch   49/134 - Train Accuracy:  0.454, Validation Accuracy:  0.473, Loss:  2.372
# Epoch   2 Batch   50/134 - Train Accuracy:  0.446, Validation Accuracy:  0.474, Loss:  2.389
# Epoch   2 Batch   51/134 - Train Accuracy:  0.450, Validation Accuracy:  0.475, Loss:  2.383
# Epoch   2 Batch   52/134 - Train Accuracy:  0.439, Validation Accuracy:  0.473, Loss:  2.409
# Epoch   2 Batch   53/134 - Train Accuracy:  0.437, Validation Accuracy:  0.471, Loss:  2.407
# Epoch   2 Batch   54/134 - Train Accuracy:  0.443, Validation Accuracy:  0.473, Loss:  2.395
# Epoch   2 Batch   55/134 - Train Accuracy:  0.447, Validation Accuracy:  0.475, Loss:  2.396
# Epoch   2 Batch   56/134 - Train Accuracy:  0.473, Validation Accuracy:  0.476, Loss:  2.274
# Epoch   2 Batch   57/134 - Train Accuracy:  0.449, Validation Accuracy:  0.472, Loss:  2.381
# Epoch   2 Batch   58/134 - Train Accuracy:  0.450, Validation Accuracy:  0.476, Loss:  2.362
# Epoch   2 Batch   59/134 - Train Accuracy:  0.429, Validation Accuracy:  0.478, Loss:  2.478
# Epoch   2 Batch   60/134 - Train Accuracy:  0.451, Validation Accuracy:  0.477, Loss:  2.357
# Epoch   2 Batch   61/134 - Train Accuracy:  0.446, Validation Accuracy:  0.476, Loss:  2.378
# Epoch   2 Batch   62/134 - Train Accuracy:  0.450, Validation Accuracy:  0.477, Loss:  2.355
# Epoch   2 Batch   63/134 - Train Accuracy:  0.453, Validation Accuracy:  0.477, Loss:  2.355
# Epoch   2 Batch   64/134 - Train Accuracy:  0.445, Validation Accuracy:  0.478, Loss:  2.391
# Epoch   2 Batch   65/134 - Train Accuracy:  0.444, Validation Accuracy:  0.475, Loss:  2.369
# Epoch   2 Batch   66/134 - Train Accuracy:  0.449, Validation Accuracy:  0.478, Loss:  2.354
# Epoch   2 Batch   67/134 - Train Accuracy:  0.416, Validation Accuracy:  0.478, Loss:  2.509
# Epoch   2 Batch   68/134 - Train Accuracy:  0.429, Validation Accuracy:  0.478, Loss:  2.450
# Epoch   2 Batch   69/134 - Train Accuracy:  0.457, Validation Accuracy:  0.480, Loss:  2.342
# Epoch   2 Batch   70/134 - Train Accuracy:  0.460, Validation Accuracy:  0.479, Loss:  2.318
# Epoch   2 Batch   71/134 - Train Accuracy:  0.455, Validation Accuracy:  0.479, Loss:  2.356
# Epoch   2 Batch   72/134 - Train Accuracy:  0.449, Validation Accuracy:  0.480, Loss:  2.350
# Epoch   2 Batch   73/134 - Train Accuracy:  0.473, Validation Accuracy:  0.478, Loss:  2.276
# Epoch   2 Batch   74/134 - Train Accuracy:  0.454, Validation Accuracy:  0.480, Loss:  2.340
# Epoch   2 Batch   75/134 - Train Accuracy:  0.477, Validation Accuracy:  0.481, Loss:  2.247
# Epoch   2 Batch   76/134 - Train Accuracy:  0.445, Validation Accuracy:  0.477, Loss:  2.367
# Epoch   2 Batch   77/134 - Train Accuracy:  0.485, Validation Accuracy:  0.482, Loss:  2.214
# Epoch   2 Batch   78/134 - Train Accuracy:  0.455, Validation Accuracy:  0.481, Loss:  2.343
# Epoch   2 Batch   79/134 - Train Accuracy:  0.453, Validation Accuracy:  0.480, Loss:  2.340
# Epoch   2 Batch   80/134 - Train Accuracy:  0.455, Validation Accuracy:  0.483, Loss:  2.351
# Epoch   2 Batch   81/134 - Train Accuracy:  0.458, Validation Accuracy:  0.482, Loss:  2.340
# Epoch   2 Batch   82/134 - Train Accuracy:  0.479, Validation Accuracy:  0.480, Loss:  2.212
# Epoch   2 Batch   83/134 - Train Accuracy:  0.454, Validation Accuracy:  0.482, Loss:  2.333
# Epoch   2 Batch   84/134 - Train Accuracy:  0.449, Validation Accuracy:  0.480, Loss:  2.333
# Epoch   2 Batch   85/134 - Train Accuracy:  0.455, Validation Accuracy:  0.482, Loss:  2.319
# Epoch   2 Batch   86/134 - Train Accuracy:  0.454, Validation Accuracy:  0.483, Loss:  2.326
# Epoch   2 Batch   87/134 - Train Accuracy:  0.453, Validation Accuracy:  0.481, Loss:  2.332
# Epoch   2 Batch   88/134 - Train Accuracy:  0.481, Validation Accuracy:  0.485, Loss:  2.224
# Epoch   2 Batch   89/134 - Train Accuracy:  0.458, Validation Accuracy:  0.484, Loss:  2.318
# Epoch   2 Batch   90/134 - Train Accuracy:  0.455, Validation Accuracy:  0.482, Loss:  2.311
# Epoch   2 Batch   91/134 - Train Accuracy:  0.527, Validation Accuracy:  0.487, Loss:  2.042
# Epoch   2 Batch   92/134 - Train Accuracy:  0.463, Validation Accuracy:  0.487, Loss:  2.286
# Epoch   2 Batch   93/134 - Train Accuracy:  0.470, Validation Accuracy:  0.485, Loss:  2.246
# Epoch   2 Batch   94/134 - Train Accuracy:  0.463, Validation Accuracy:  0.484, Loss:  2.284
# Epoch   2 Batch   95/134 - Train Accuracy:  0.459, Validation Accuracy:  0.483, Loss:  2.305
# Epoch   2 Batch   96/134 - Train Accuracy:  0.459, Validation Accuracy:  0.483, Loss:  2.309
# Epoch   2 Batch   97/134 - Train Accuracy:  0.451, Validation Accuracy:  0.482, Loss:  2.319
# Epoch   2 Batch   98/134 - Train Accuracy:  0.423, Validation Accuracy:  0.481, Loss:  2.431
# Epoch   2 Batch   99/134 - Train Accuracy:  0.459, Validation Accuracy:  0.486, Loss:  2.312
# Epoch   2 Batch  100/134 - Train Accuracy:  0.461, Validation Accuracy:  0.489, Loss:  2.313
# Epoch   2 Batch  101/134 - Train Accuracy:  0.441, Validation Accuracy:  0.487, Loss:  2.378
# Epoch   2 Batch  102/134 - Train Accuracy:  0.460, Validation Accuracy:  0.491, Loss:  2.311
# Epoch   2 Batch  103/134 - Train Accuracy:  0.489, Validation Accuracy:  0.493, Loss:  2.207
# Epoch   2 Batch  104/134 - Train Accuracy:  0.461, Validation Accuracy:  0.485, Loss:  2.270
# Epoch   2 Batch  105/134 - Train Accuracy:  0.474, Validation Accuracy:  0.493, Loss:  2.260
# Epoch   2 Batch  106/134 - Train Accuracy:  0.470, Validation Accuracy:  0.492, Loss:  2.266
# Epoch   2 Batch  107/134 - Train Accuracy:  0.488, Validation Accuracy:  0.487, Loss:  2.171
# Epoch   2 Batch  108/134 - Train Accuracy:  0.440, Validation Accuracy:  0.493, Loss:  2.389
# Epoch   2 Batch  109/134 - Train Accuracy:  0.493, Validation Accuracy:  0.494, Loss:  2.171
# Epoch   2 Batch  110/134 - Train Accuracy:  0.472, Validation Accuracy:  0.491, Loss:  2.240
# Epoch   2 Batch  111/134 - Train Accuracy:  0.472, Validation Accuracy:  0.496, Loss:  2.244
# Epoch   2 Batch  112/134 - Train Accuracy:  0.470, Validation Accuracy:  0.493, Loss:  2.252
# Epoch   2 Batch  113/134 - Train Accuracy:  0.533, Validation Accuracy:  0.491, Loss:  1.996
# Epoch   2 Batch  114/134 - Train Accuracy:  0.464, Validation Accuracy:  0.491, Loss:  2.266
# Epoch   2 Batch  115/134 - Train Accuracy:  0.436, Validation Accuracy:  0.492, Loss:  2.385
# Epoch   2 Batch  116/134 - Train Accuracy:  0.470, Validation Accuracy:  0.496, Loss:  2.281
# Epoch   2 Batch  117/134 - Train Accuracy:  0.464, Validation Accuracy:  0.493, Loss:  2.254
# Epoch   2 Batch  118/134 - Train Accuracy:  0.466, Validation Accuracy:  0.490, Loss:  2.247
# Epoch   2 Batch  119/134 - Train Accuracy:  0.513, Validation Accuracy:  0.497, Loss:  2.078
# Epoch   2 Batch  120/134 - Train Accuracy:  0.467, Validation Accuracy:  0.494, Loss:  2.234
# Epoch   2 Batch  121/134 - Train Accuracy:  0.472, Validation Accuracy:  0.490, Loss:  2.231
# Epoch   2 Batch  122/134 - Train Accuracy:  0.471, Validation Accuracy:  0.499, Loss:  2.250
# Epoch   2 Batch  123/134 - Train Accuracy:  0.475, Validation Accuracy:  0.498, Loss:  2.235
# Epoch   2 Batch  124/134 - Train Accuracy:  0.497, Validation Accuracy:  0.495, Loss:  2.133
# Epoch   2 Batch  125/134 - Train Accuracy:  0.467, Validation Accuracy:  0.497, Loss:  2.267
# Epoch   2 Batch  126/134 - Train Accuracy:  0.470, Validation Accuracy:  0.496, Loss:  2.241
# Epoch   2 Batch  127/134 - Train Accuracy:  0.489, Validation Accuracy:  0.498, Loss:  2.173
# Epoch   2 Batch  128/134 - Train Accuracy:  0.462, Validation Accuracy:  0.497, Loss:  2.254
# Epoch   2 Batch  129/134 - Train Accuracy:  0.473, Validation Accuracy:  0.494, Loss:  2.226
# Epoch   2 Batch  130/134 - Train Accuracy:  0.465, Validation Accuracy:  0.499, Loss:  2.261
# Epoch   2 Batch  131/134 - Train Accuracy:  0.452, Validation Accuracy:  0.499, Loss:  2.324
# Epoch   2 Batch  132/134 - Train Accuracy:  0.472, Validation Accuracy:  0.496, Loss:  2.222
# Epoch   3 Batch    0/134 - Train Accuracy:  0.462, Validation Accuracy:  0.496, Loss:  2.254
# Epoch   3 Batch    1/134 - Train Accuracy:  0.446, Validation Accuracy:  0.497, Loss:  2.324
# Epoch   3 Batch    2/134 - Train Accuracy:  0.475, Validation Accuracy:  0.499, Loss:  2.208
# Epoch   3 Batch    3/134 - Train Accuracy:  0.475, Validation Accuracy:  0.497, Loss:  2.206
# Epoch   3 Batch    4/134 - Train Accuracy:  0.472, Validation Accuracy:  0.498, Loss:  2.219
# Epoch   3 Batch    5/134 - Train Accuracy:  0.473, Validation Accuracy:  0.499, Loss:  2.222
# Epoch   3 Batch    6/134 - Train Accuracy:  0.496, Validation Accuracy:  0.498, Loss:  2.105
# Epoch   3 Batch    7/134 - Train Accuracy:  0.465, Validation Accuracy:  0.496, Loss:  2.236
# Epoch   3 Batch    8/134 - Train Accuracy:  0.467, Validation Accuracy:  0.499, Loss:  2.206
# Epoch   3 Batch    9/134 - Train Accuracy:  0.503, Validation Accuracy:  0.498, Loss:  2.108
# Epoch   3 Batch   10/134 - Train Accuracy:  0.477, Validation Accuracy:  0.497, Loss:  2.215
# Epoch   3 Batch   11/134 - Train Accuracy:  0.478, Validation Accuracy:  0.498, Loss:  2.192
# Epoch   3 Batch   12/134 - Train Accuracy:  0.501, Validation Accuracy:  0.499, Loss:  2.099
# Epoch   3 Batch   13/134 - Train Accuracy:  0.461, Validation Accuracy:  0.499, Loss:  2.238
# Epoch   3 Batch   14/134 - Train Accuracy:  0.468, Validation Accuracy:  0.498, Loss:  2.215
# Epoch   3 Batch   15/134 - Train Accuracy:  0.469, Validation Accuracy:  0.500, Loss:  2.194
# Epoch   3 Batch   16/134 - Train Accuracy:  0.477, Validation Accuracy:  0.500, Loss:  2.182
# Epoch   3 Batch   17/134 - Train Accuracy:  0.476, Validation Accuracy:  0.503, Loss:  2.190
# Epoch   3 Batch   18/134 - Train Accuracy:  0.473, Validation Accuracy:  0.500, Loss:  2.210
# Epoch   3 Batch   19/134 - Train Accuracy:  0.474, Validation Accuracy:  0.500, Loss:  2.182
# Epoch   3 Batch   20/134 - Train Accuracy:  0.495, Validation Accuracy:  0.500, Loss:  2.102
# Epoch   3 Batch   21/134 - Train Accuracy:  0.477, Validation Accuracy:  0.498, Loss:  2.153
# Epoch   3 Batch   22/134 - Train Accuracy:  0.452, Validation Accuracy:  0.501, Loss:  2.298
# Epoch   3 Batch   23/134 - Train Accuracy:  0.502, Validation Accuracy:  0.501, Loss:  2.057
# Epoch   3 Batch   24/134 - Train Accuracy:  0.454, Validation Accuracy:  0.501, Loss:  2.258
# Epoch   3 Batch   25/134 - Train Accuracy:  0.473, Validation Accuracy:  0.504, Loss:  2.185
# Epoch   3 Batch   26/134 - Train Accuracy:  0.453, Validation Accuracy:  0.502, Loss:  2.274
# Epoch   3 Batch   27/134 - Train Accuracy:  0.480, Validation Accuracy:  0.502, Loss:  2.165
# Epoch   3 Batch   28/134 - Train Accuracy:  0.479, Validation Accuracy:  0.503, Loss:  2.167
# Epoch   3 Batch   29/134 - Train Accuracy:  0.492, Validation Accuracy:  0.501, Loss:  2.088
# Epoch   3 Batch   30/134 - Train Accuracy:  0.498, Validation Accuracy:  0.502, Loss:  2.078
# Epoch   3 Batch   31/134 - Train Accuracy:  0.474, Validation Accuracy:  0.502, Loss:  2.161
# Epoch   3 Batch   32/134 - Train Accuracy:  0.494, Validation Accuracy:  0.501, Loss:  2.088
# Epoch   3 Batch   33/134 - Train Accuracy:  0.471, Validation Accuracy:  0.504, Loss:  2.174
# Epoch   3 Batch   34/134 - Train Accuracy:  0.480, Validation Accuracy:  0.500, Loss:  2.172
# Epoch   3 Batch   35/134 - Train Accuracy:  0.499, Validation Accuracy:  0.503, Loss:  2.079
# Epoch   3 Batch   36/134 - Train Accuracy:  0.481, Validation Accuracy:  0.502, Loss:  2.141
# Epoch   3 Batch   37/134 - Train Accuracy:  0.466, Validation Accuracy:  0.502, Loss:  2.180
# Epoch   3 Batch   38/134 - Train Accuracy:  0.481, Validation Accuracy:  0.504, Loss:  2.166
# Epoch   3 Batch   39/134 - Train Accuracy:  0.477, Validation Accuracy:  0.501, Loss:  2.130
# Epoch   3 Batch   40/134 - Train Accuracy:  0.485, Validation Accuracy:  0.505, Loss:  2.138
# Epoch   3 Batch   41/134 - Train Accuracy:  0.480, Validation Accuracy:  0.502, Loss:  2.129
# Epoch   3 Batch   42/134 - Train Accuracy:  0.471, Validation Accuracy:  0.506, Loss:  2.169
# Epoch   3 Batch   43/134 - Train Accuracy:  0.476, Validation Accuracy:  0.505, Loss:  2.167
# Epoch   3 Batch   44/134 - Train Accuracy:  0.478, Validation Accuracy:  0.505, Loss:  2.144
# Epoch   3 Batch   45/134 - Train Accuracy:  0.482, Validation Accuracy:  0.506, Loss:  2.135
# Epoch   3 Batch   46/134 - Train Accuracy:  0.496, Validation Accuracy:  0.504, Loss:  2.061
# Epoch   3 Batch   47/134 - Train Accuracy:  0.483, Validation Accuracy:  0.507, Loss:  2.134
# Epoch   3 Batch   48/134 - Train Accuracy:  0.486, Validation Accuracy:  0.505, Loss:  2.116
# Epoch   3 Batch   49/134 - Train Accuracy:  0.491, Validation Accuracy:  0.507, Loss:  2.112
# Epoch   3 Batch   50/134 - Train Accuracy:  0.480, Validation Accuracy:  0.506, Loss:  2.124
# Epoch   3 Batch   51/134 - Train Accuracy:  0.477, Validation Accuracy:  0.506, Loss:  2.123
# Epoch   3 Batch   52/134 - Train Accuracy:  0.472, Validation Accuracy:  0.505, Loss:  2.146
# Epoch   3 Batch   53/134 - Train Accuracy:  0.474, Validation Accuracy:  0.506, Loss:  2.143
# Epoch   3 Batch   54/134 - Train Accuracy:  0.471, Validation Accuracy:  0.505, Loss:  2.127
# Epoch   3 Batch   55/134 - Train Accuracy:  0.477, Validation Accuracy:  0.507, Loss:  2.133
# Epoch   3 Batch   56/134 - Train Accuracy:  0.502, Validation Accuracy:  0.508, Loss:  2.024
# Epoch   3 Batch   57/134 - Train Accuracy:  0.482, Validation Accuracy:  0.504, Loss:  2.118
# Epoch   3 Batch   58/134 - Train Accuracy:  0.485, Validation Accuracy:  0.506, Loss:  2.101
# Epoch   3 Batch   59/134 - Train Accuracy:  0.452, Validation Accuracy:  0.502, Loss:  2.220
# Epoch   3 Batch   60/134 - Train Accuracy:  0.477, Validation Accuracy:  0.501, Loss:  2.116
# Epoch   3 Batch   61/134 - Train Accuracy:  0.473, Validation Accuracy:  0.504, Loss:  2.138
# Epoch   3 Batch   62/134 - Train Accuracy:  0.481, Validation Accuracy:  0.505, Loss:  2.097
# Epoch   3 Batch   63/134 - Train Accuracy:  0.487, Validation Accuracy:  0.507, Loss:  2.098
# Epoch   3 Batch   64/134 - Train Accuracy:  0.472, Validation Accuracy:  0.504, Loss:  2.140
# Epoch   3 Batch   65/134 - Train Accuracy:  0.483, Validation Accuracy:  0.508, Loss:  2.113
# Epoch   3 Batch   66/134 - Train Accuracy:  0.477, Validation Accuracy:  0.507, Loss:  2.095
# Epoch   3 Batch   67/134 - Train Accuracy:  0.445, Validation Accuracy:  0.503, Loss:  2.243
# Epoch   3 Batch   68/134 - Train Accuracy:  0.462, Validation Accuracy:  0.506, Loss:  2.190
# Epoch   3 Batch   69/134 - Train Accuracy:  0.488, Validation Accuracy:  0.507, Loss:  2.094
# Epoch   3 Batch   70/134 - Train Accuracy:  0.490, Validation Accuracy:  0.505, Loss:  2.066
# Epoch   3 Batch   71/134 - Train Accuracy:  0.483, Validation Accuracy:  0.507, Loss:  2.108
# Epoch   3 Batch   72/134 - Train Accuracy:  0.478, Validation Accuracy:  0.508, Loss:  2.101
# Epoch   3 Batch   73/134 - Train Accuracy:  0.499, Validation Accuracy:  0.506, Loss:  2.032
# Epoch   3 Batch   74/134 - Train Accuracy:  0.482, Validation Accuracy:  0.507, Loss:  2.088
# Epoch   3 Batch   75/134 - Train Accuracy:  0.508, Validation Accuracy:  0.509, Loss:  2.005
# Epoch   3 Batch   76/134 - Train Accuracy:  0.477, Validation Accuracy:  0.506, Loss:  2.112
# Epoch   3 Batch   77/134 - Train Accuracy:  0.515, Validation Accuracy:  0.509, Loss:  1.973
# Epoch   3 Batch   78/134 - Train Accuracy:  0.482, Validation Accuracy:  0.509, Loss:  2.097
# Epoch   3 Batch   79/134 - Train Accuracy:  0.482, Validation Accuracy:  0.507, Loss:  2.096
# Epoch   3 Batch   80/134 - Train Accuracy:  0.479, Validation Accuracy:  0.509, Loss:  2.101
# Epoch   3 Batch   81/134 - Train Accuracy:  0.484, Validation Accuracy:  0.509, Loss:  2.092
# Epoch   3 Batch   82/134 - Train Accuracy:  0.505, Validation Accuracy:  0.508, Loss:  1.972
# Epoch   3 Batch   83/134 - Train Accuracy:  0.484, Validation Accuracy:  0.509, Loss:  2.086
# Epoch   3 Batch   84/134 - Train Accuracy:  0.477, Validation Accuracy:  0.508, Loss:  2.086
# Epoch   3 Batch   85/134 - Train Accuracy:  0.485, Validation Accuracy:  0.509, Loss:  2.068
# Epoch   3 Batch   86/134 - Train Accuracy:  0.480, Validation Accuracy:  0.508, Loss:  2.080
# Epoch   3 Batch   87/134 - Train Accuracy:  0.482, Validation Accuracy:  0.509, Loss:  2.092
# Epoch   3 Batch   88/134 - Train Accuracy:  0.503, Validation Accuracy:  0.509, Loss:  1.992
# Epoch   3 Batch   89/134 - Train Accuracy:  0.483, Validation Accuracy:  0.509, Loss:  2.070
# Epoch   3 Batch   90/134 - Train Accuracy:  0.482, Validation Accuracy:  0.508, Loss:  2.071
# Epoch   3 Batch   91/134 - Train Accuracy:  0.550, Validation Accuracy:  0.510, Loss:  1.821
# Epoch   3 Batch   92/134 - Train Accuracy:  0.490, Validation Accuracy:  0.509, Loss:  2.042
# Epoch   3 Batch   93/134 - Train Accuracy:  0.491, Validation Accuracy:  0.508, Loss:  2.009
# Epoch   3 Batch   94/134 - Train Accuracy:  0.489, Validation Accuracy:  0.510, Loss:  2.047
# Epoch   3 Batch   95/134 - Train Accuracy:  0.482, Validation Accuracy:  0.508, Loss:  2.066
# Epoch   3 Batch   96/134 - Train Accuracy:  0.482, Validation Accuracy:  0.506, Loss:  2.071
# Epoch   3 Batch   97/134 - Train Accuracy:  0.475, Validation Accuracy:  0.508, Loss:  2.081
# Epoch   3 Batch   98/134 - Train Accuracy:  0.456, Validation Accuracy:  0.510, Loss:  2.176
# Epoch   3 Batch   99/134 - Train Accuracy:  0.483, Validation Accuracy:  0.509, Loss:  2.063
# Epoch   3 Batch  100/134 - Train Accuracy:  0.480, Validation Accuracy:  0.510, Loss:  2.073
# Epoch   3 Batch  101/134 - Train Accuracy:  0.465, Validation Accuracy:  0.510, Loss:  2.128
# Epoch   3 Batch  102/134 - Train Accuracy:  0.477, Validation Accuracy:  0.509, Loss:  2.069
# Epoch   3 Batch  103/134 - Train Accuracy:  0.504, Validation Accuracy:  0.510, Loss:  1.976
# Epoch   3 Batch  104/134 - Train Accuracy:  0.484, Validation Accuracy:  0.510, Loss:  2.035
# Epoch   3 Batch  105/134 - Train Accuracy:  0.491, Validation Accuracy:  0.509, Loss:  2.017
# Epoch   3 Batch  106/134 - Train Accuracy:  0.490, Validation Accuracy:  0.509, Loss:  2.026
# Epoch   3 Batch  107/134 - Train Accuracy:  0.508, Validation Accuracy:  0.509, Loss:  1.947
# Epoch   3 Batch  108/134 - Train Accuracy:  0.459, Validation Accuracy:  0.509, Loss:  2.138
# Epoch   3 Batch  109/134 - Train Accuracy:  0.508, Validation Accuracy:  0.510, Loss:  1.942
# Epoch   3 Batch  110/134 - Train Accuracy:  0.491, Validation Accuracy:  0.509, Loss:  2.006
# Epoch   3 Batch  111/134 - Train Accuracy:  0.488, Validation Accuracy:  0.508, Loss:  2.006
# Epoch   3 Batch  112/134 - Train Accuracy:  0.482, Validation Accuracy:  0.507, Loss:  2.016
# Epoch   3 Batch  113/134 - Train Accuracy:  0.549, Validation Accuracy:  0.509, Loss:  1.787
# Epoch   3 Batch  114/134 - Train Accuracy:  0.482, Validation Accuracy:  0.511, Loss:  2.029
# Epoch   3 Batch  115/134 - Train Accuracy:  0.456, Validation Accuracy:  0.510, Loss:  2.132
# Epoch   3 Batch  116/134 - Train Accuracy:  0.482, Validation Accuracy:  0.509, Loss:  2.042
# ...
# Epoch  98 Batch   95/134 - Train Accuracy:  0.922, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  98 Batch   96/134 - Train Accuracy:  0.919, Validation Accuracy:  0.925, Loss:  0.040
# Epoch  98 Batch   97/134 - Train Accuracy:  0.910, Validation Accuracy:  0.923, Loss:  0.044
# Epoch  98 Batch   98/134 - Train Accuracy:  0.911, Validation Accuracy:  0.923, Loss:  0.043
# Epoch  98 Batch   99/134 - Train Accuracy:  0.917, Validation Accuracy:  0.923, Loss:  0.043
# Epoch  98 Batch  100/134 - Train Accuracy:  0.914, Validation Accuracy:  0.922, Loss:  0.045
# Epoch  98 Batch  101/134 - Train Accuracy:  0.919, Validation Accuracy:  0.920, Loss:  0.045
# Epoch  98 Batch  102/134 - Train Accuracy:  0.917, Validation Accuracy:  0.919, Loss:  0.044
# Epoch  98 Batch  103/134 - Train Accuracy:  0.909, Validation Accuracy:  0.921, Loss:  0.041
# Epoch  98 Batch  104/134 - Train Accuracy:  0.921, Validation Accuracy:  0.922, Loss:  0.042
# Epoch  98 Batch  105/134 - Train Accuracy:  0.920, Validation Accuracy:  0.923, Loss:  0.046
# Epoch  98 Batch  106/134 - Train Accuracy:  0.909, Validation Accuracy:  0.920, Loss:  0.043
# Epoch  98 Batch  107/134 - Train Accuracy:  0.922, Validation Accuracy:  0.922, Loss:  0.045
# Epoch  98 Batch  108/134 - Train Accuracy:  0.921, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  98 Batch  109/134 - Train Accuracy:  0.921, Validation Accuracy:  0.921, Loss:  0.041
# Epoch  98 Batch  110/134 - Train Accuracy:  0.931, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  98 Batch  111/134 - Train Accuracy:  0.915, Validation Accuracy:  0.924, Loss:  0.044
# Epoch  98 Batch  112/134 - Train Accuracy:  0.916, Validation Accuracy:  0.922, Loss:  0.041
# Epoch  98 Batch  113/134 - Train Accuracy:  0.926, Validation Accuracy:  0.922, Loss:  0.045
# Epoch  98 Batch  114/134 - Train Accuracy:  0.920, Validation Accuracy:  0.922, Loss:  0.044
# Epoch  98 Batch  115/134 - Train Accuracy:  0.915, Validation Accuracy:  0.920, Loss:  0.043
# Epoch  98 Batch  116/134 - Train Accuracy:  0.924, Validation Accuracy:  0.923, Loss:  0.044
# Epoch  98 Batch  117/134 - Train Accuracy:  0.931, Validation Accuracy:  0.919, Loss:  0.039
# Epoch  98 Batch  118/134 - Train Accuracy:  0.916, Validation Accuracy:  0.921, Loss:  0.041
# Epoch  98 Batch  119/134 - Train Accuracy:  0.931, Validation Accuracy:  0.920, Loss:  0.038
# Epoch  98 Batch  120/134 - Train Accuracy:  0.922, Validation Accuracy:  0.921, Loss:  0.044
# Epoch  98 Batch  121/134 - Train Accuracy:  0.919, Validation Accuracy:  0.923, Loss:  0.040
# Epoch  98 Batch  122/134 - Train Accuracy:  0.919, Validation Accuracy:  0.920, Loss:  0.042
# Epoch  98 Batch  123/134 - Train Accuracy:  0.930, Validation Accuracy:  0.920, Loss:  0.040
# Epoch  98 Batch  124/134 - Train Accuracy:  0.926, Validation Accuracy:  0.920, Loss:  0.037
# Epoch  98 Batch  125/134 - Train Accuracy:  0.931, Validation Accuracy:  0.920, Loss:  0.038
# Epoch  98 Batch  126/134 - Train Accuracy:  0.908, Validation Accuracy:  0.921, Loss:  0.043
# Epoch  98 Batch  127/134 - Train Accuracy:  0.919, Validation Accuracy:  0.923, Loss:  0.041
# Epoch  98 Batch  128/134 - Train Accuracy:  0.907, Validation Accuracy:  0.924, Loss:  0.046
# Epoch  98 Batch  129/134 - Train Accuracy:  0.925, Validation Accuracy:  0.922, Loss:  0.045
# Epoch  98 Batch  130/134 - Train Accuracy:  0.917, Validation Accuracy:  0.924, Loss:  0.041
# Epoch  98 Batch  131/134 - Train Accuracy:  0.913, Validation Accuracy:  0.924, Loss:  0.047
# Epoch  98 Batch  132/134 - Train Accuracy:  0.917, Validation Accuracy:  0.922, Loss:  0.040
# Epoch  99 Batch    0/134 - Train Accuracy:  0.918, Validation Accuracy:  0.922, Loss:  0.043
# Epoch  99 Batch    1/134 - Train Accuracy:  0.918, Validation Accuracy:  0.922, Loss:  0.042
# Epoch  99 Batch    2/134 - Train Accuracy:  0.925, Validation Accuracy:  0.921, Loss:  0.040
# Epoch  99 Batch    3/134 - Train Accuracy:  0.922, Validation Accuracy:  0.922, Loss:  0.043
# Epoch  99 Batch    4/134 - Train Accuracy:  0.917, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  99 Batch    5/134 - Train Accuracy:  0.922, Validation Accuracy:  0.923, Loss:  0.046
# Epoch  99 Batch    6/134 - Train Accuracy:  0.919, Validation Accuracy:  0.924, Loss:  0.038
# Epoch  99 Batch    7/134 - Train Accuracy:  0.919, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  99 Batch    8/134 - Train Accuracy:  0.923, Validation Accuracy:  0.924, Loss:  0.042
# Epoch  99 Batch    9/134 - Train Accuracy:  0.925, Validation Accuracy:  0.925, Loss:  0.037
# Epoch  99 Batch   10/134 - Train Accuracy:  0.917, Validation Accuracy:  0.922, Loss:  0.043
# Epoch  99 Batch   11/134 - Train Accuracy:  0.920, Validation Accuracy:  0.923, Loss:  0.041
# Epoch  99 Batch   12/134 - Train Accuracy:  0.927, Validation Accuracy:  0.920, Loss:  0.042
# Epoch  99 Batch   13/134 - Train Accuracy:  0.903, Validation Accuracy:  0.923, Loss:  0.045
# Epoch  99 Batch   14/134 - Train Accuracy:  0.919, Validation Accuracy:  0.923, Loss:  0.044
# Epoch  99 Batch   15/134 - Train Accuracy:  0.919, Validation Accuracy:  0.923, Loss:  0.041
# Epoch  99 Batch   16/134 - Train Accuracy:  0.926, Validation Accuracy:  0.924, Loss:  0.039
# Epoch  99 Batch   17/134 - Train Accuracy:  0.916, Validation Accuracy:  0.923, Loss:  0.049
# Epoch  99 Batch   18/134 - Train Accuracy:  0.919, Validation Accuracy:  0.923, Loss:  0.040
# Epoch  99 Batch   19/134 - Train Accuracy:  0.912, Validation Accuracy:  0.924, Loss:  0.046
# Epoch  99 Batch   20/134 - Train Accuracy:  0.921, Validation Accuracy:  0.922, Loss:  0.040
# Epoch  99 Batch   21/134 - Train Accuracy:  0.918, Validation Accuracy:  0.924, Loss:  0.043
# Epoch  99 Batch   22/134 - Train Accuracy:  0.922, Validation Accuracy:  0.923, Loss:  0.041
# Epoch  99 Batch   23/134 - Train Accuracy:  0.925, Validation Accuracy:  0.920, Loss:  0.038
# Epoch  99 Batch   24/134 - Train Accuracy:  0.910, Validation Accuracy:  0.922, Loss:  0.043
# Epoch  99 Batch   25/134 - Train Accuracy:  0.914, Validation Accuracy:  0.923, Loss:  0.038
# Epoch  99 Batch   26/134 - Train Accuracy:  0.912, Validation Accuracy:  0.924, Loss:  0.043
# Epoch  99 Batch   27/134 - Train Accuracy:  0.917, Validation Accuracy:  0.925, Loss:  0.041
# Epoch  99 Batch   28/134 - Train Accuracy:  0.921, Validation Accuracy:  0.925, Loss:  0.043
# Epoch  99 Batch   29/134 - Train Accuracy:  0.925, Validation Accuracy:  0.923, Loss:  0.035
# Epoch  99 Batch   30/134 - Train Accuracy:  0.925, Validation Accuracy:  0.923, Loss:  0.041
# Epoch  99 Batch   31/134 - Train Accuracy:  0.916, Validation Accuracy:  0.922, Loss:  0.042
# Epoch  99 Batch   32/134 - Train Accuracy:  0.920, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  99 Batch   33/134 - Train Accuracy:  0.910, Validation Accuracy:  0.921, Loss:  0.048
# Epoch  99 Batch   34/134 - Train Accuracy:  0.910, Validation Accuracy:  0.922, Loss:  0.046
# Epoch  99 Batch   35/134 - Train Accuracy:  0.921, Validation Accuracy:  0.924, Loss:  0.044
# Epoch  99 Batch   36/134 - Train Accuracy:  0.922, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  99 Batch   37/134 - Train Accuracy:  0.915, Validation Accuracy:  0.922, Loss:  0.042
# Epoch  99 Batch   38/134 - Train Accuracy:  0.924, Validation Accuracy:  0.922, Loss:  0.041
# Epoch  99 Batch   39/134 - Train Accuracy:  0.919, Validation Accuracy:  0.921, Loss:  0.044
# Epoch  99 Batch   40/134 - Train Accuracy:  0.916, Validation Accuracy:  0.924, Loss:  0.042
# Epoch  99 Batch   41/134 - Train Accuracy:  0.914, Validation Accuracy:  0.925, Loss:  0.051
# Epoch  99 Batch   42/134 - Train Accuracy:  0.926, Validation Accuracy:  0.923, Loss:  0.040
# Epoch  99 Batch   43/134 - Train Accuracy:  0.915, Validation Accuracy:  0.923, Loss:  0.043
# Epoch  99 Batch   44/134 - Train Accuracy:  0.918, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  99 Batch   45/134 - Train Accuracy:  0.927, Validation Accuracy:  0.921, Loss:  0.039
# Epoch  99 Batch   46/134 - Train Accuracy:  0.923, Validation Accuracy:  0.921, Loss:  0.043
# Epoch  99 Batch   47/134 - Train Accuracy:  0.911, Validation Accuracy:  0.921, Loss:  0.043
# Epoch  99 Batch   48/134 - Train Accuracy:  0.930, Validation Accuracy:  0.924, Loss:  0.044
# Epoch  99 Batch   49/134 - Train Accuracy:  0.924, Validation Accuracy:  0.922, Loss:  0.042
# Epoch  99 Batch   50/134 - Train Accuracy:  0.913, Validation Accuracy:  0.921, Loss:  0.045
# Epoch  99 Batch   51/134 - Train Accuracy:  0.911, Validation Accuracy:  0.920, Loss:  0.044
# Epoch  99 Batch   52/134 - Train Accuracy:  0.920, Validation Accuracy:  0.922, Loss:  0.041
# Epoch  99 Batch   53/134 - Train Accuracy:  0.926, Validation Accuracy:  0.924, Loss:  0.040
# Epoch  99 Batch   54/134 - Train Accuracy:  0.904, Validation Accuracy:  0.923, Loss:  0.044
# Epoch  99 Batch   55/134 - Train Accuracy:  0.914, Validation Accuracy:  0.922, Loss:  0.046
# Epoch  99 Batch   56/134 - Train Accuracy:  0.923, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  99 Batch   57/134 - Train Accuracy:  0.924, Validation Accuracy:  0.921, Loss:  0.044
# Epoch  99 Batch   58/134 - Train Accuracy:  0.919, Validation Accuracy:  0.922, Loss:  0.041
# Epoch  99 Batch   59/134 - Train Accuracy:  0.917, Validation Accuracy:  0.921, Loss:  0.043
# Epoch  99 Batch   60/134 - Train Accuracy:  0.926, Validation Accuracy:  0.923, Loss:  0.039
# Epoch  99 Batch   61/134 - Train Accuracy:  0.915, Validation Accuracy:  0.924, Loss:  0.038
# Epoch  99 Batch   62/134 - Train Accuracy:  0.912, Validation Accuracy:  0.922, Loss:  0.041
# Epoch  99 Batch   63/134 - Train Accuracy:  0.922, Validation Accuracy:  0.922, Loss:  0.041
# Epoch  99 Batch   64/134 - Train Accuracy:  0.916, Validation Accuracy:  0.923, Loss:  0.043
# Epoch  99 Batch   65/134 - Train Accuracy:  0.904, Validation Accuracy:  0.923, Loss:  0.043
# Epoch  99 Batch   66/134 - Train Accuracy:  0.919, Validation Accuracy:  0.924, Loss:  0.038
# Epoch  99 Batch   67/134 - Train Accuracy:  0.910, Validation Accuracy:  0.922, Loss:  0.042
# Epoch  99 Batch   68/134 - Train Accuracy:  0.915, Validation Accuracy:  0.923, Loss:  0.045
# Epoch  99 Batch   69/134 - Train Accuracy:  0.914, Validation Accuracy:  0.921, Loss:  0.046
# Epoch  99 Batch   70/134 - Train Accuracy:  0.918, Validation Accuracy:  0.923, Loss:  0.043
# Epoch  99 Batch   71/134 - Train Accuracy:  0.931, Validation Accuracy:  0.923, Loss:  0.036
# Epoch  99 Batch   72/134 - Train Accuracy:  0.919, Validation Accuracy:  0.923, Loss:  0.040
# Epoch  99 Batch   73/134 - Train Accuracy:  0.917, Validation Accuracy:  0.926, Loss:  0.044
# Epoch  99 Batch   74/134 - Train Accuracy:  0.912, Validation Accuracy:  0.924, Loss:  0.049
# Epoch  99 Batch   75/134 - Train Accuracy:  0.918, Validation Accuracy:  0.926, Loss:  0.045
# Epoch  99 Batch   76/134 - Train Accuracy:  0.929, Validation Accuracy:  0.925, Loss:  0.041
# Epoch  99 Batch   77/134 - Train Accuracy:  0.911, Validation Accuracy:  0.924, Loss:  0.041
# Epoch  99 Batch   78/134 - Train Accuracy:  0.917, Validation Accuracy:  0.926, Loss:  0.042
# Epoch  99 Batch   79/134 - Train Accuracy:  0.916, Validation Accuracy:  0.924, Loss:  0.041
# Epoch  99 Batch   80/134 - Train Accuracy:  0.928, Validation Accuracy:  0.924, Loss:  0.042
# Epoch  99 Batch   81/134 - Train Accuracy:  0.924, Validation Accuracy:  0.925, Loss:  0.043
# Epoch  99 Batch   82/134 - Train Accuracy:  0.922, Validation Accuracy:  0.924, Loss:  0.039
# Epoch  99 Batch   83/134 - Train Accuracy:  0.916, Validation Accuracy:  0.922, Loss:  0.042
# Epoch  99 Batch   84/134 - Train Accuracy:  0.907, Validation Accuracy:  0.921, Loss:  0.041
# Epoch  99 Batch   85/134 - Train Accuracy:  0.919, Validation Accuracy:  0.924, Loss:  0.044
# Epoch  99 Batch   86/134 - Train Accuracy:  0.923, Validation Accuracy:  0.923, Loss:  0.041
# Epoch  99 Batch   87/134 - Train Accuracy:  0.918, Validation Accuracy:  0.921, Loss:  0.048
# Epoch  99 Batch   88/134 - Train Accuracy:  0.920, Validation Accuracy:  0.922, Loss:  0.038
# Epoch  99 Batch   89/134 - Train Accuracy:  0.921, Validation Accuracy:  0.921, Loss:  0.040
# Epoch  99 Batch   90/134 - Train Accuracy:  0.916, Validation Accuracy:  0.920, Loss:  0.042
# Epoch  99 Batch   91/134 - Train Accuracy:  0.928, Validation Accuracy:  0.922, Loss:  0.035
# Epoch  99 Batch   92/134 - Train Accuracy:  0.928, Validation Accuracy:  0.924, Loss:  0.039
# Epoch  99 Batch   93/134 - Train Accuracy:  0.921, Validation Accuracy:  0.925, Loss:  0.042
# Epoch  99 Batch   94/134 - Train Accuracy:  0.917, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  99 Batch   95/134 - Train Accuracy:  0.923, Validation Accuracy:  0.925, Loss:  0.041
# Epoch  99 Batch   96/134 - Train Accuracy:  0.920, Validation Accuracy:  0.926, Loss:  0.039
# Epoch  99 Batch   97/134 - Train Accuracy:  0.910, Validation Accuracy:  0.924, Loss:  0.043
# Epoch  99 Batch   98/134 - Train Accuracy:  0.913, Validation Accuracy:  0.925, Loss:  0.042
# Epoch  99 Batch   99/134 - Train Accuracy:  0.921, Validation Accuracy:  0.924, Loss:  0.042
# Epoch  99 Batch  100/134 - Train Accuracy:  0.913, Validation Accuracy:  0.922, Loss:  0.044
# Epoch  99 Batch  101/134 - Train Accuracy:  0.920, Validation Accuracy:  0.921, Loss:  0.044
# Epoch  99 Batch  102/134 - Train Accuracy:  0.917, Validation Accuracy:  0.920, Loss:  0.043
# Epoch  99 Batch  103/134 - Train Accuracy:  0.912, Validation Accuracy:  0.921, Loss:  0.040
# Epoch  99 Batch  104/134 - Train Accuracy:  0.921, Validation Accuracy:  0.924, Loss:  0.041
# Epoch  99 Batch  105/134 - Train Accuracy:  0.920, Validation Accuracy:  0.924, Loss:  0.045
# Epoch  99 Batch  106/134 - Train Accuracy:  0.912, Validation Accuracy:  0.921, Loss:  0.042
# Epoch  99 Batch  107/134 - Train Accuracy:  0.923, Validation Accuracy:  0.922, Loss:  0.044
# Epoch  99 Batch  108/134 - Train Accuracy:  0.923, Validation Accuracy:  0.923, Loss:  0.042
# Epoch  99 Batch  109/134 - Train Accuracy:  0.923, Validation Accuracy:  0.923, Loss:  0.040
# Epoch  99 Batch  110/134 - Train Accuracy:  0.932, Validation Accuracy:  0.925, Loss:  0.041
# Epoch  99 Batch  111/134 - Train Accuracy:  0.915, Validation Accuracy:  0.924, Loss:  0.043
# Epoch  99 Batch  112/134 - Train Accuracy:  0.917, Validation Accuracy:  0.923, Loss:  0.040
# Epoch  99 Batch  113/134 - Train Accuracy:  0.927, Validation Accuracy:  0.923, Loss:  0.045
# Epoch  99 Batch  114/134 - Train Accuracy:  0.920, Validation Accuracy:  0.923, Loss:  0.043
# Epoch  99 Batch  115/134 - Train Accuracy:  0.916, Validation Accuracy:  0.922, Loss:  0.042
# Epoch  99 Batch  116/134 - Train Accuracy:  0.923, Validation Accuracy:  0.923, Loss:  0.043
# Epoch  99 Batch  117/134 - Train Accuracy:  0.931, Validation Accuracy:  0.922, Loss:  0.039
# Epoch  99 Batch  118/134 - Train Accuracy:  0.916, Validation Accuracy:  0.921, Loss:  0.040
# Epoch  99 Batch  119/134 - Train Accuracy:  0.930, Validation Accuracy:  0.922, Loss:  0.037
# Epoch  99 Batch  120/134 - Train Accuracy:  0.921, Validation Accuracy:  0.922, Loss:  0.044
# Epoch  99 Batch  121/134 - Train Accuracy:  0.923, Validation Accuracy:  0.922, Loss:  0.039
# Epoch  99 Batch  122/134 - Train Accuracy:  0.921, Validation Accuracy:  0.920, Loss:  0.042
# Epoch  99 Batch  123/134 - Train Accuracy:  0.929, Validation Accuracy:  0.919, Loss:  0.040
# Epoch  99 Batch  124/134 - Train Accuracy:  0.928, Validation Accuracy:  0.921, Loss:  0.036
# Epoch  99 Batch  125/134 - Train Accuracy:  0.931, Validation Accuracy:  0.921, Loss:  0.037
# Epoch  99 Batch  126/134 - Train Accuracy:  0.909, Validation Accuracy:  0.923, Loss:  0.043
# Epoch  99 Batch  127/134 - Train Accuracy:  0.919, Validation Accuracy:  0.923, Loss:  0.041
# Epoch  99 Batch  128/134 - Train Accuracy:  0.910, Validation Accuracy:  0.926, Loss:  0.046
# Epoch  99 Batch  129/134 - Train Accuracy:  0.925, Validation Accuracy:  0.925, Loss:  0.045
# Epoch  99 Batch  130/134 - Train Accuracy:  0.917, Validation Accuracy:  0.923, Loss:  0.041
# Epoch  99 Batch  131/134 - Train Accuracy:  0.914, Validation Accuracy:  0.927, Loss:  0.046
# Epoch  99 Batch  132/134 - Train Accuracy:  0.919, Validation Accuracy:  0.923, Loss:  0.040
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in sentence.lower().split()]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'the united states is usually chilly during july , and it is usually freezing in november .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# Input
#   Word Ids:      [86, 47, 172, 135, 229, 51, 176, 143, 81, 7, 14, 135, 229, 137, 41, 127, 212]
#   English Words: ['the', 'united', 'states', 'is', 'usually', 'chilly', 'during', 'july', ',', 'and', 'it', 'is', 'usually', 'freezing', 'in', 'november', '.']
#
# Prediction
#   Word Ids:      [5, 231, 154, 17, 51, 80, 31, 134, 55, 22, 185, 166, 80, 297, 273, 1]
#   French Words: ['les', 'états-unis', 'est', 'généralement', 'froid', 'en', 'juillet', ',', 'et', 'il', 'gèle', 'habituellement', 'en', 'novembre', '.', '<EOS>']

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
